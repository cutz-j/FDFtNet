# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
from keras import backend as K
# os.environ["CUDA_VISIBLE_DEVICES"] = '1'
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)
K.set_session(sess)
from keras import regularizers
from keras.regularizers import l2
from keras.layers import Input, Dense, Flatten, GlobalAveragePooling2D, Activation, Conv2D, MaxPooling2D, BatchNormalization, Lambda, Dropout
from keras.layers import SeparableConv2D, Add, Convolution2D, concatenate, Layer, ReLU, DepthwiseConv2D, Reshape, Multiply, InputSpec
from keras.models import Model, load_model, model_from_json
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam, SGD
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.utils import to_categorical
from sklearn import metrics
from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
from scipy.optimize import brentq
from scipy.interpolate import interp1d
import glob
from PIL import Image
# from tqdm import trange
import random
from keras.applications import Xception, ResNet152
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
import cv2
# Out:
# Using TensorFlow backend.

# %%
nb_classes = 2  # number of classes
img_width, img_height = 64, 64  # change based on the shape/structure of your images
batch_size = 64  # try 4, 8, 16, 32, 64, 128, 256 dependent on CPU/GPU memory capacity (powers of 2 values).
nb_epoch = 300  # number of iteration the algorithm gets trained.

# %%
def bgr(img):
    return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
train_dir = '/mnt/a/fakedata/face2face/train'
validation_dir = '/mnt/a/fakedata/face2face/val'
test50_dir = '/mnt/a/fakedata/face2face/test'

# %%
sq1x1 = "squeeze1x1"
exp1x1 = "expand1x1"
exp3x3 = "expand3x3"
relu = "relu_"
# Modular function for Fire Node

def fire_module(x, fire_id, squeeze=16, expand=64):
    s_id = 'fire' + str(fire_id) + '/'

    if K.image_data_format() == 'channels_first':
        channel_axis = 1
    else:
        channel_axis = 3
    
    x = Convolution2D(squeeze, (1, 1), padding='valid', name=s_id + sq1x1)(x)
    x = BatchNormalization()(x)
    x = Activation('relu', name=s_id + relu + sq1x1)(x)

    left = Convolution2D(expand, (1, 1), padding='valid', name=s_id + exp1x1)(x)
#     left = BatchNormalization()(left)
    left = Activation('relu', name=s_id + relu + exp1x1)(left)

    right = Convolution2D(expand, (3, 3), padding='same', name=s_id + exp3x3)(x)
#     right = BatchNormalization()(right)
    right = Activation('relu', name=s_id + relu + exp3x3)(right)

    x = concatenate([left, right], axis=channel_axis, name=s_id + 'concat')
    return x


# Original SqueezeNet from paper.



img_input = Input(shape=(img_height, img_width, 3))

x = Convolution2D(64, (3, 3), strides=(2, 2), padding='valid', name='conv1')(img_input)
# x = BatchNormalization()(x)
x = Activation('relu', name='relu_conv1')(x)
x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool1')(x)

x = fire_module(x, fire_id=2, squeeze=16, expand=64)
x = fire_module(x, fire_id=3, squeeze=16, expand=64)
x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool3')(x)

x = fire_module(x, fire_id=4, squeeze=32, expand=128)
x = fire_module(x, fire_id=5, squeeze=32, expand=128)
x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool5')(x)

x = fire_module(x, fire_id=6, squeeze=48, expand=192)
x = fire_module(x, fire_id=7, squeeze=48, expand=192)
x = fire_module(x, fire_id=8, squeeze=64, expand=256)
x = fire_module(x, fire_id=9, squeeze=64, expand=256)

# x_dp = Dropout(0.5, name='drop9')(x)
x_conv = Convolution2D(nb_classes, (1, 1), padding='valid', name='conv10')(x)
x_relu = Activation('relu', name='relu_conv10')(x_conv)
x_gap = GlobalAveragePooling2D()(x_relu)
x_sm = Activation('softmax', name='loss')(x_gap)

model = Model(img_input, x_sm, name='squeezenet')
model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1007 15:19:41.065145 15812 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# Model: "squeezenet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 31, 31, 64)   1792        input_1[0][0]
# __________________________________________________________________________________________________
# relu_conv1 (Activation)         (None, 31, 31, 64)   0           conv1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 15, 15, 64)   0           relu_conv1[0][0]
# __________________________________________________________________________________________________
# fire2/squeeze1x1 (Conv2D)       (None, 15, 15, 16)   1040        pool1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 15, 15, 16)   64          fire2/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire2/relu_squeeze1x1 (Activati (None, 15, 15, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# fire2/expand1x1 (Conv2D)        (None, 15, 15, 64)   1088        fire2/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire2/expand3x3 (Conv2D)        (None, 15, 15, 64)   9280        fire2/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire2/relu_expand1x1 (Activatio (None, 15, 15, 64)   0           fire2/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire2/relu_expand3x3 (Activatio (None, 15, 15, 64)   0           fire2/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire2/concat (Concatenate)      (None, 15, 15, 128)  0           fire2/relu_expand1x1[0][0]
#                                                                  fire2/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire3/squeeze1x1 (Conv2D)       (None, 15, 15, 16)   2064        fire2/concat[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 15, 15, 16)   64          fire3/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire3/relu_squeeze1x1 (Activati (None, 15, 15, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# fire3/expand1x1 (Conv2D)        (None, 15, 15, 64)   1088        fire3/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire3/expand3x3 (Conv2D)        (None, 15, 15, 64)   9280        fire3/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire3/relu_expand1x1 (Activatio (None, 15, 15, 64)   0           fire3/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire3/relu_expand3x3 (Activatio (None, 15, 15, 64)   0           fire3/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire3/concat (Concatenate)      (None, 15, 15, 128)  0           fire3/relu_expand1x1[0][0]
#                                                                  fire3/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# pool3 (MaxPooling2D)            (None, 7, 7, 128)    0           fire3/concat[0][0]
# __________________________________________________________________________________________________
# fire4/squeeze1x1 (Conv2D)       (None, 7, 7, 32)     4128        pool3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 7, 7, 32)     128         fire4/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire4/relu_squeeze1x1 (Activati (None, 7, 7, 32)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# fire4/expand1x1 (Conv2D)        (None, 7, 7, 128)    4224        fire4/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire4/expand3x3 (Conv2D)        (None, 7, 7, 128)    36992       fire4/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire4/relu_expand1x1 (Activatio (None, 7, 7, 128)    0           fire4/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire4/relu_expand3x3 (Activatio (None, 7, 7, 128)    0           fire4/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire4/concat (Concatenate)      (None, 7, 7, 256)    0           fire4/relu_expand1x1[0][0]
#                                                                  fire4/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire5/squeeze1x1 (Conv2D)       (None, 7, 7, 32)     8224        fire4/concat[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 7, 7, 32)     128         fire5/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire5/relu_squeeze1x1 (Activati (None, 7, 7, 32)     0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# fire5/expand1x1 (Conv2D)        (None, 7, 7, 128)    4224        fire5/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire5/expand3x3 (Conv2D)        (None, 7, 7, 128)    36992       fire5/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire5/relu_expand1x1 (Activatio (None, 7, 7, 128)    0           fire5/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire5/relu_expand3x3 (Activatio (None, 7, 7, 128)    0           fire5/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire5/concat (Concatenate)      (None, 7, 7, 256)    0           fire5/relu_expand1x1[0][0]
#                                                                  fire5/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# pool5 (MaxPooling2D)            (None, 3, 3, 256)    0           fire5/concat[0][0]
# __________________________________________________________________________________________________
# fire6/squeeze1x1 (Conv2D)       (None, 3, 3, 48)     12336       pool5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 3, 3, 48)     192         fire6/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire6/relu_squeeze1x1 (Activati (None, 3, 3, 48)     0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# fire6/expand1x1 (Conv2D)        (None, 3, 3, 192)    9408        fire6/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire6/expand3x3 (Conv2D)        (None, 3, 3, 192)    83136       fire6/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire6/relu_expand1x1 (Activatio (None, 3, 3, 192)    0           fire6/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire6/relu_expand3x3 (Activatio (None, 3, 3, 192)    0           fire6/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire6/concat (Concatenate)      (None, 3, 3, 384)    0           fire6/relu_expand1x1[0][0]
#                                                                  fire6/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire7/squeeze1x1 (Conv2D)       (None, 3, 3, 48)     18480       fire6/concat[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 3, 3, 48)     192         fire7/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire7/relu_squeeze1x1 (Activati (None, 3, 3, 48)     0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# fire7/expand1x1 (Conv2D)        (None, 3, 3, 192)    9408        fire7/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire7/expand3x3 (Conv2D)        (None, 3, 3, 192)    83136       fire7/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire7/relu_expand1x1 (Activatio (None, 3, 3, 192)    0           fire7/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire7/relu_expand3x3 (Activatio (None, 3, 3, 192)    0           fire7/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire7/concat (Concatenate)      (None, 3, 3, 384)    0           fire7/relu_expand1x1[0][0]
#                                                                  fire7/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire8/squeeze1x1 (Conv2D)       (None, 3, 3, 64)     24640       fire7/concat[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 3, 3, 64)     256         fire8/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire8/relu_squeeze1x1 (Activati (None, 3, 3, 64)     0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# fire8/expand1x1 (Conv2D)        (None, 3, 3, 256)    16640       fire8/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire8/expand3x3 (Conv2D)        (None, 3, 3, 256)    147712      fire8/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire8/relu_expand1x1 (Activatio (None, 3, 3, 256)    0           fire8/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire8/relu_expand3x3 (Activatio (None, 3, 3, 256)    0           fire8/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire8/concat (Concatenate)      (None, 3, 3, 512)    0           fire8/relu_expand1x1[0][0]
#                                                                  fire8/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire9/squeeze1x1 (Conv2D)       (None, 3, 3, 64)     32832       fire8/concat[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 3, 3, 64)     256         fire9/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire9/relu_squeeze1x1 (Activati (None, 3, 3, 64)     0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# fire9/expand1x1 (Conv2D)        (None, 3, 3, 256)    16640       fire9/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire9/expand3x3 (Conv2D)        (None, 3, 3, 256)    147712      fire9/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire9/relu_expand1x1 (Activatio (None, 3, 3, 256)    0           fire9/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire9/relu_expand3x3 (Activatio (None, 3, 3, 256)    0           fire9/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire9/concat (Concatenate)      (None, 3, 3, 512)    0           fire9/relu_expand1x1[0][0]
#                                                                  fire9/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# conv10 (Conv2D)                 (None, 3, 3, 2)      1026        fire9/concat[0][0]
# __________________________________________________________________________________________________
# relu_conv10 (Activation)        (None, 3, 3, 2)      0           conv10[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 2)            0           relu_conv10[0][0]
# __________________________________________________________________________________________________
# loss (Activation)               (None, 2)            0           global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 724,802
# Trainable params: 724,162
# Non-trainable params: 640
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=Adam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

print(len(model.trainable_weights))
# Out:
# 68

# %%
train_datagen = ImageDataGenerator(rescale=1./255, preprocessing_function=bgr)

test_datagen = ImageDataGenerator(rescale=1./255, preprocessing_function=bgr)

train_generator = train_datagen.flow_from_directory(train_dir,
                                                        target_size=(img_height, img_width),
                                                        batch_size=batch_size,
                                                        shuffle=True,
                                                        class_mode='categorical')

validation_generator = train_datagen.flow_from_directory(validation_dir,
                                                        target_size=(img_height, img_width),
                                                        batch_size=batch_size,
                                                        shuffle=False,
                                                        class_mode='categorical')

test50_generator = test_datagen.flow_from_directory(test50_dir,
                                                  target_size=(img_height, img_width),
                                                  batch_size=batch_size,
                                                  shuffle=False,
                                                  class_mode='categorical')
# Out:
# Found 60000 images belonging to 2 classes.
# Found 18000 images belonging to 2 classes.
# Found 20000 images belonging to 2 classes.

# %%
# callback_list = [EarlyStopping(monitor='val_accuracy', patience=10),
#                  ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3)]
# history = model.fit_generator(train_generator,
#                             steps_per_epoch=200,
#                             epochs=100,
#                             validation_data=validation_generator,
#                             validation_steps=len(validation_generator),
#                             callbacks=callback_list)

# %%
# model.save('/home/www/fake_detection/model/face2face_squeezenet.h5')

# %%
# model = load_model('/home/www/fake_detection/model/face2face_squeezenet.h5')

# %%
# output = model.predict_generator(test50_generator, steps=len(test50_generator), verbose=1)
# np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
# print(test50_generator.class_indices)
# print(output)

# %%
# output_score50 = []
# output_class50 = []
# answer_class50 = []
# answer_class50_1 =[]

# for i in trange(len(test50_generator)):
#     output50 = model.predict_on_batch(test50_generator[i][0])
#     output_score50.append(output50)
#     answer_class50.append(test50_generator[i][1])
    
# output_score50 = np.concatenate(output_score50)
# answer_class50 = np.concatenate(answer_class50)

# output_class50 = np.argmax(output_score50, axis=1)
# answer_class50_1 = np.argmax(answer_class50, axis=1)

# print(output_class50)
# print(answer_class50_1)

# %%
# cm50 = confusion_matrix(answer_class50_1, output_class50)
# report50 = classification_report(answer_class50_1, output_class50)

# recall50 = cm50[0][0] / (cm50[0][0] + cm50[0][1])
# fallout50 = cm50[1][0] / (cm50[1][0] + cm50[1][1])

# fpr50, tpr50, thresholds50 = roc_curve(answer_class50_1, output_score50[:, 1], pos_label=1.)
# eer50 = brentq(lambda x : 1. - x - interp1d(fpr50, tpr50)(x), 0., 1.)
# thresh50 = interp1d(fpr50, thresholds50)(eer50)

# print(report50)
# print(cm50)
# print("AUROC: %f" %(roc_auc_score(answer_class50_1, output_score50[:, 1])))
# print(thresh50)
# print('test_acc: ', len(output_class50[np.equal(output_class50, answer_class50_1)]) / len(output_class50))

# %%
def cutout(img):
    """
    # Function: RandomCrop (ZeroPadded (4, 4)) + random occulusion image
    # Arguments:
        img: image
    # Returns:
        img
    """
    img = bgr(img)
    height = img.shape[0]
    width = img.shape[1]
    channels = img.shape[2]
    MAX_CUTS = 3 # chance to get more cuts
    MAX_LENGTH_MUTIPLIER = 5 # chance to get larger cuts
    # 16 for cifar10, 8 for cifar100
    
    # Zero-padded (4, 4)
#     img = np.pad(img, ((4,4),(4,4),(0,0)), mode='constant', constant_values=(0))
    
#     # random-crop 64x64
#     dy, dx = height, width
#     x = np.random.randint(0, width - dx + 1)
#     y = np.random.randint(0, height - dy + 1)
#     img = img[y:(y+dy), x:(x+dx)]
    
#     mean norm
#     mean = img.mean(keepdims=True)
#     img -= mean

    img *= 1./255
    
    mask = np.ones((height, width, channels), dtype=np.float32)
    nb_cuts = np.random.randint(0, MAX_CUTS + 1)
    
    # cutout
    for i in range(nb_cuts):
        y = np.random.randint(height)
        x = np.random.randint(width)
        length = 4 * np.random.randint(1, MAX_LENGTH_MUTIPLIER+1)
        
        y1 = np.clip(y-length//2, 0, height)
        y2 = np.clip(y+length//2, 0, height)
        x1 = np.clip(x-length//2, 0, width)
        x2 = np.clip(x+length//2, 0, width)
        
        mask[y1:y2, x1:x2, :] = 0.
    
    img = img * mask
    return img

# %%
class ReLU6(Layer):
    def __init__(self):
        super().__init__(name="ReLU6")
        self.relu6 = ReLU(max_value=6, name="ReLU6")

    def call(self, input):
        return self.relu6(input)


class HardSigmoid(Layer):
    def __init__(self):
        super().__init__()
        self.relu6 = ReLU6()

    def call(self, input):
        return self.relu6(input + 3.0) / 6.0


class HardSwish(Layer):
    def __init__(self):
        super().__init__()
        self.hard_sigmoid = HardSigmoid()

    def call(self, input):
        return input * self.hard_sigmoid(input)
    
class Attention(Layer):
    def __init__(self, ch, **kwargs):
        super(Attention, self).__init__(**kwargs)
        self.channels = ch
        self.filters_f_g = self.channels // 8
        self.filters_h = self.channels

    def build(self, input_shape):
        kernel_shape_f_g = (1, 1) + (self.channels, self.filters_f_g)
        print(kernel_shape_f_g)
        kernel_shape_h = (1, 1) + (self.channels, self.filters_h)

        # Create a trainable weight variable for this layer:
        self.gamma = self.add_weight(name='gamma', shape=[1], initializer='zeros', trainable=True)
        self.kernel_f = self.add_weight(shape=kernel_shape_f_g,
                                        initializer='glorot_uniform',
                                        name='kernel_f')
        self.kernel_g = self.add_weight(shape=kernel_shape_f_g,
                                        initializer='glorot_uniform',
                                        name='kernel_g')
        self.kernel_h = self.add_weight(shape=kernel_shape_h,
                                        initializer='glorot_uniform',
                                        name='kernel_h')
        self.bias_f = self.add_weight(shape=(self.filters_f_g,),
                                      initializer='zeros',
                                      name='bias_F')
        self.bias_g = self.add_weight(shape=(self.filters_f_g,),
                                      initializer='zeros',
                                      name='bias_g')
        self.bias_h = self.add_weight(shape=(self.filters_h,),
                                      initializer='zeros',
                                      name='bias_h')
        super(Attention, self).build(input_shape)
        # Set input spec.
        self.input_spec = InputSpec(ndim=4,
                                    axes={3: input_shape[-1]})
        self.built = True


    def call(self, x):
        def hw_flatten(x):
            return K.reshape(x, shape=[K.shape(x)[0], K.shape(x)[1]*K.shape(x)[2], K.shape(x)[-1]])

        f = K.conv2d(x,
                     kernel=self.kernel_f,
                     strides=(1, 1), padding='same')  # [bs, h, w, c']
        f = K.bias_add(f, self.bias_f)
        g = K.conv2d(x,
                     kernel=self.kernel_g,
                     strides=(1, 1), padding='same')  # [bs, h, w, c']
        g = K.bias_add(g, self.bias_g)
        h = K.conv2d(x,
                     kernel=self.kernel_h,
                     strides=(1, 1), padding='same')  # [bs, h, w, c]
        h = K.bias_add(h, self.bias_h)

        s = tf.matmul(hw_flatten(g), hw_flatten(f), transpose_b=True)  # # [bs, N, N]

        beta = K.softmax(s, axis=-1)  # attention map

        o = K.batch_dot(beta, hw_flatten(h))  # [bs, N, C]

        o = K.reshape(o, shape=K.shape(x))  # [bs, h, w, C]
        x = self.gamma * o + x

        return x

    def compute_output_shape(self, input_shape):
        return input_shape

# %%
ft_dir = '/mnt/a/fakedata/face2face/finetune'
train_gen_aug = ImageDataGenerator(shear_range=0, 
                               zoom_range=0,
                               rotation_range=0.2,
                               width_shift_range=2., 
                               height_shift_range=2.,
                               horizontal_flip=True,
                               zca_whitening=False,
                               fill_mode='nearest',
                               preprocessing_function=cutout)

test_datagen = ImageDataGenerator(rescale=1./255, preprocessing_function=bgr)

ft_gen = train_gen_aug.flow_from_directory(ft_dir,
                                              target_size=(img_height, img_width),
                                              batch_size=batch_size,
                                              shuffle=True,
                                              class_mode='categorical')


validation_generator = test_datagen.flow_from_directory(validation_dir,
                                                        target_size=(img_height, img_width),
                                                        batch_size=batch_size,
                                                        shuffle=False,
                                                        class_mode='categorical')

test50_generator = test_datagen.flow_from_directory(test50_dir,
                                                  target_size=(img_height, img_width),
                                                  batch_size=batch_size,
                                                  shuffle=False,
                                                  class_mode='categorical')
# Out:
# Found 2000 images belonging to 2 classes.
# Found 18000 images belonging to 2 classes.
# Found 20000 images belonging to 2 classes.

# %%
model_ft = load_model('/home/www/fake_detection/model/face2face_squeezenet.h5')
for i in range(5):
    model_ft.layers.pop()
im_in = Input(shape=(img_width, img_height, 3))

base_model = Model(img_input, x)
base_model.set_weights(model_ft.get_weights())
# for i in range(len(base_model.layers) - 0):
#     base_model.layers[i].trainable = False
    
x1 = base_model(im_in) # (12, 12, 32)
########### Mobilenet block bneck 3x3 (32 --> 128) #################
expand1 = Conv2D(576, kernel_size=1, strides=1, kernel_regularizer=l2(1e-5), use_bias=False)(x1)
expand1 = BatchNormalization()(expand1)
expand1 = HardSwish()(expand1)
dw1 = DepthwiseConv2D(kernel_size=(3,3), strides=(2,2), padding='same', depthwise_regularizer=l2(1e-5), use_bias=False)(expand1)
dw1 = BatchNormalization()(dw1)
se_gap1 = GlobalAveragePooling2D()(dw1)
se_gap1 = Reshape([1, 1, -1])(se_gap1)
se1 = Conv2D(144, kernel_size=1, strides=1, padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(se_gap1)
se1 = Activation('relu')(se1)
se1 = Conv2D(576, kernel_size=1, strides=1, padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(se1)
se1 = HardSigmoid()(se1)
se1 = Multiply()([expand1, se1])
project1 = HardSwish()(se1)
project1 = Conv2D(128, kernel_size=(1, 1), padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(project1)
project1 = BatchNormalization()(project1)

########### Mobilenet block bneck 5x5 (128 --> 128) #################
expand2 = Conv2D(576, kernel_size=1, strides=1, kernel_regularizer=l2(1e-5), use_bias=False)(project1)
expand2 = BatchNormalization()(expand2)
expand2 = HardSwish()(expand2)
dw2 = DepthwiseConv2D(kernel_size=(5,5), strides=(1,1), padding='same', depthwise_regularizer=l2(1e-5), use_bias=False)(expand2)
dw2 = BatchNormalization()(dw2)
se_gap2 = GlobalAveragePooling2D()(dw2)
se_gap2 = Reshape([1, 1, -1])(se_gap2)
se2 = Conv2D(144, kernel_size=1, strides=1, padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(se_gap2)
se2 = Activation('relu')(se2)
se2 = Conv2D(576, kernel_size=1, strides=1, padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(se2)
se2 = HardSigmoid()(se2)
se2 = Multiply()([expand2, se2])
project2 = HardSwish()(se2)
project2 = Conv2D(128, kernel_size=(1, 1), padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(project2)
project2 = BatchNormalization()(project2)
project2 = Add()([project1, project2])

########### Mobilenet block bneck 5x5 (128 --> 128) #################
expand3 = Conv2D(576, kernel_size=1, strides=1, kernel_regularizer=l2(1e-5), use_bias=False)(project2)
expand3 = BatchNormalization()(expand3)
expand3 = HardSwish()(expand3)
dw3 = DepthwiseConv2D(kernel_size=(5,5), strides=(1,1), padding='same', depthwise_regularizer=l2(1e-5), use_bias=False)(expand3)
dw3 = BatchNormalization()(dw3)
se_gap3 = GlobalAveragePooling2D()(dw3)
se_gap3 = Reshape([1, 1, -1])(se_gap3)
se3 = Conv2D(144, kernel_size=1, strides=1, padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(se_gap3)
se3 = Activation('relu')(se3)
se3 = Conv2D(576, kernel_size=1, strides=1, padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(se3)
se3 = HardSigmoid()(se3)
se3 = Multiply()([expand3, se3])
project3 = HardSwish()(se3)
project3 = Conv2D(128, kernel_size=(1, 1), padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(project3)
project3 = BatchNormalization()(project3)
project3 = Add()([project2, project3])


expand4 = Conv2D(576, kernel_size=1, strides=1, kernel_regularizer=l2(1e-5), use_bias=False)(project3)
expand4 = BatchNormalization()(expand4)
expand4 = HardSwish()(expand4)
dw4 = DepthwiseConv2D(kernel_size=(5,5), strides=(1,1), padding='same', depthwise_regularizer=l2(1e-5), use_bias=False)(expand4)
dw4 = BatchNormalization()(dw4)
se_gap4 = GlobalAveragePooling2D()(dw4)
se_gap4 = Reshape([1, 1, -1])(se_gap4)
se4 = Conv2D(144, kernel_size=1, strides=1, padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(se_gap4)
se4 = Activation('relu')(se4)
se4 = Conv2D(576, kernel_size=1, strides=1, padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(se4)
se4 = HardSigmoid()(se4)
se4 = Multiply()([expand4, se4])
project4 = HardSwish()(se4)
project4 = Conv2D(128, kernel_size=(1, 1), padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(project4)
project4 = BatchNormalization()(project4)
project4 = Add()([project3, project4])


########## Classification ##########
x2 = Conv2D(576, kernel_size=1, strides=1, padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(project4)
x2 = BatchNormalization()(x2)
x2 = HardSwish()(x2)
x2 = GlobalAveragePooling2D()(x2)


######### Image Attention Model #########
### Block 1 ###
x3 = SeparableConv2D(32, kernel_size=(3, 3), strides=(2,2), padding='same', depthwise_regularizer=l2(1e-5), pointwise_regularizer=l2(1e-5), use_bias=False)(im_in)
x3 = BatchNormalization()(x3)
x3 = Activation('relu')(x3)
x3 = Attention(32)(x3)

### Block 2 ###
x4 = SeparableConv2D(64, kernel_size=(3, 3), strides=(2,2), padding='same', depthwise_regularizer=l2(1e-5), pointwise_regularizer=l2(1e-5), use_bias=False)(x3)
x4 = BatchNormalization()(x4)
x4 = Activation('relu')(x4)
x4 = Attention(64)(x4)

### Block 3 ###
x5 = SeparableConv2D(128, kernel_size=(3, 3), strides=(2,2), padding='same', depthwise_regularizer=l2(1e-5), pointwise_regularizer=l2(1e-5), use_bias=False)(x4)
x5 = BatchNormalization()(x5)
x5 = Activation('relu')(x5)
x5 = Attention(128)(x5)

### final stage ###
x6 = Conv2D(576, kernel_size=1, strides=1, padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(x5)
x6 = BatchNormalization()(x6)
x6 = Activation('relu')(x6)
x6 = GlobalAveragePooling2D()(x6)
# x6 = Reshape([1, 1, -1])(x6)

######## final addition #########

x2 = Add()([x2, x6])
x2 = Dense(2, kernel_regularizer=l2(1e-5))(x2)
x2 = Activation('softmax')(x2)

model_top = Model(inputs=im_in, outputs=x2)
model_top.summary()
# Out:
# W1007 15:20:01.165857 15812 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# (1, 1, 32, 4)
# (1, 1, 64, 8)
# (1, 1, 128, 16)
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# model_1 (Model)                 (None, 3, 3, 512)    723776      input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 3, 3, 576)    294912      model_1[1][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 3, 3, 576)    2304        conv2d_1[0][0]
# __________________________________________________________________________________________________
# hard_swish_1 (HardSwish)        (None, 3, 3, 576)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 2, 2, 576)    5184        hard_swish_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 2, 2, 576)    2304        depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 576)          0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 576)    0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 1, 1, 144)    82944       reshape_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1, 1, 144)    0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 1, 1, 576)    82944       activation_1[0][0]
# __________________________________________________________________________________________________
# hard_sigmoid_2 (HardSigmoid)    (None, 1, 1, 576)    0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 3, 3, 576)    0           hard_swish_1[0][0]
#                                                                  hard_sigmoid_2[0][0]
# __________________________________________________________________________________________________
# hard_swish_2 (HardSwish)        (None, 3, 3, 576)    0           multiply_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 3, 3, 128)    73728       hard_swish_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 3, 3, 128)    512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 3, 3, 576)    73728       batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 3, 3, 576)    2304        conv2d_5[0][0]
# __________________________________________________________________________________________________
# hard_swish_3 (HardSwish)        (None, 3, 3, 576)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 3, 3, 576)    14400       hard_swish_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 3, 3, 576)    2304        depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 576)          0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 576)    0           global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 1, 144)    82944       reshape_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1, 1, 144)    0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 1, 1, 576)    82944       activation_2[0][0]
# __________________________________________________________________________________________________
# hard_sigmoid_5 (HardSigmoid)    (None, 1, 1, 576)    0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 3, 3, 576)    0           hard_swish_3[0][0]
#                                                                  hard_sigmoid_5[0][0]
# __________________________________________________________________________________________________
# hard_swish_4 (HardSwish)        (None, 3, 3, 576)    0           multiply_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 3, 3, 128)    73728       hard_swish_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 3, 3, 128)    512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 3, 3, 128)    0           batch_normalization_11[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 3, 3, 576)    73728       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 3, 3, 576)    2304        conv2d_9[0][0]
# __________________________________________________________________________________________________
# hard_swish_5 (HardSwish)        (None, 3, 3, 576)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (None, 3, 3, 576)    14400       hard_swish_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 3, 3, 576)    2304        depthwise_conv2d_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 576)          0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 576)    0           global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 1, 1, 144)    82944       reshape_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 1, 1, 144)    0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 1, 1, 576)    82944       activation_3[0][0]
# __________________________________________________________________________________________________
# hard_sigmoid_8 (HardSigmoid)    (None, 1, 1, 576)    0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 3, 3, 576)    0           hard_swish_5[0][0]
#                                                                  hard_sigmoid_8[0][0]
# __________________________________________________________________________________________________
# hard_swish_6 (HardSwish)        (None, 3, 3, 576)    0           multiply_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 3, 3, 128)    73728       hard_swish_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 3, 3, 128)    512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 3, 3, 128)    0           add_1[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 3, 3, 576)    73728       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 3, 3, 576)    2304        conv2d_13[0][0]
# __________________________________________________________________________________________________
# hard_swish_7 (HardSwish)        (None, 3, 3, 576)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (None, 3, 3, 576)    14400       hard_swish_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 3, 3, 576)    2304        depthwise_conv2d_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 32, 32, 32)   123         input_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 576)          0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 32, 32, 32)   128         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 1, 576)    0           global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 32)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 1, 1, 144)    82944       reshape_4[0][0]
# __________________________________________________________________________________________________
# attention_1 (Attention)         (None, 32, 32, 32)   1321        activation_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1, 1, 144)    0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 16, 16, 64)   2336        attention_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 1, 1, 576)    82944       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 16, 16, 64)   256         separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# hard_sigmoid_11 (HardSigmoid)   (None, 1, 1, 576)    0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 3, 3, 576)    0           hard_swish_7[0][0]
#                                                                  hard_sigmoid_11[0][0]
# __________________________________________________________________________________________________
# attention_2 (Attention)         (None, 16, 16, 64)   5201        activation_6[0][0]
# __________________________________________________________________________________________________
# hard_swish_8 (HardSwish)        (None, 3, 3, 576)    0           multiply_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 8, 8, 128)    8768        attention_2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 3, 3, 128)    73728       hard_swish_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 8, 8, 128)    512         separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 3, 3, 128)    512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 8, 8, 128)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 3, 3, 128)    0           add_2[0][0]
#                                                                  batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# attention_3 (Attention)         (None, 8, 8, 128)    20641       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 3, 3, 576)    73728       add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 576)    73728       attention_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 3, 3, 576)    2304        conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 8, 576)    2304        conv2d_18[0][0]
# __________________________________________________________________________________________________
# hard_swish_9 (HardSwish)        (None, 3, 3, 576)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 8, 8, 576)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 576)          0           hard_swish_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 576)          0           activation_8[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 576)          0           global_average_pooling2d_6[0][0]
#                                                                  global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            1154        add_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 2)            0           dense_1[0][0]
# ==================================================================================================
# Total params: 2,459,704
# Trainable params: 2,446,072
# Non-trainable params: 13,632
# __________________________________________________________________________________________________

# %%
# optimizer = SGD(lr=1e-3, momentum=0.9, nesterov=True)
optimizer = Adam()
model_top.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['acc'])
callback_list = [EarlyStopping(monitor='val_acc', patience=30), 
                 ReduceLROnPlateau(monitor='loss', factor=np.sqrt(0.5), cooldown=0, patience=5, min_lr=0.5e-5)]
output = model_top.fit_generator(ft_gen, steps_per_epoch=200, epochs=300,
                                  validation_data=validation_generator, validation_steps=len(validation_generator), callbacks=callback_list)
# Out:
# Epoch 1/300
# 200/200 [==============================] - 894s 4s/step - loss: 0.7691 - acc: 0.5149 - val_loss: 0.3069 - val_acc: 0.5000
# Epoch 2/300
# 200/200 [==============================] - 931s 5s/step - loss: 0.7304 - acc: 0.5462 - val_loss: 0.0885 - val_acc: 0.5000
# Epoch 3/300
# 200/200 [==============================] - 929s 5s/step - loss: 0.6965 - acc: 0.5902 - val_loss: 0.2103 - val_acc: 0.5031
# Epoch 4/300
# 200/200 [==============================] - 917s 5s/step - loss: 0.6606 - acc: 0.6228 - val_loss: 0.9924 - val_acc: 0.5927
# Epoch 5/300
# 200/200 [==============================] - 927s 5s/step - loss: 0.6450 - acc: 0.6318 - val_loss: 1.0861 - val_acc: 0.6129
# Epoch 6/300
# 200/200 [==============================] - 920s 5s/step - loss: 0.6286 - acc: 0.6469 - val_loss: 1.3833 - val_acc: 0.5411
# Epoch 7/300
# 200/200 [==============================] - 943s 5s/step - loss: 0.6100 - acc: 0.6594 - val_loss: 1.0374 - val_acc: 0.5464
# Epoch 8/300
# 200/200 [==============================] - 957s 5s/step - loss: 0.5990 - acc: 0.6658 - val_loss: 1.0935 - val_acc: 0.6244
# Epoch 9/300
# 200/200 [==============================] - 921s 5s/step - loss: 0.5872 - acc: 0.6775 - val_loss: 0.6967 - val_acc: 0.6702
# Epoch 10/300
# 200/200 [==============================] - 904s 5s/step - loss: 0.5695 - acc: 0.6867 - val_loss: 1.0488 - val_acc: 0.6514
# Epoch 11/300
# 200/200 [==============================] - 896s 4s/step - loss: 0.5491 - acc: 0.7104 - val_loss: 0.5540 - val_acc: 0.6768
# Epoch 12/300
# 200/200 [==============================] - 885s 4s/step - loss: 0.5415 - acc: 0.7053 - val_loss: 0.7857 - val_acc: 0.6799
# Epoch 13/300
# 200/200 [==============================] - 889s 4s/step - loss: 0.5263 - acc: 0.7244 - val_loss: 0.5313 - val_acc: 0.6946
# Epoch 14/300
# 200/200 [==============================] - 879s 4s/step - loss: 0.5164 - acc: 0.7291 - val_loss: 0.7138 - val_acc: 0.6844
# Epoch 15/300
# 200/200 [==============================] - 905s 5s/step - loss: 0.5115 - acc: 0.7340 - val_loss: 0.9464 - val_acc: 0.6411
# Epoch 16/300
# 200/200 [==============================] - 881s 4s/step - loss: 0.4950 - acc: 0.7439 - val_loss: 1.3117 - val_acc: 0.5571
# Epoch 17/300
# 200/200 [==============================] - 896s 4s/step - loss: 0.4773 - acc: 0.7564 - val_loss: 0.8399 - val_acc: 0.6512
# Epoch 18/300
# 200/200 [==============================] - 938s 5s/step - loss: 0.4741 - acc: 0.7590 - val_loss: 0.5329 - val_acc: 0.7157
# Epoch 19/300
# 200/200 [==============================] - 922s 5s/step - loss: 0.4585 - acc: 0.7685 - val_loss: 0.2691 - val_acc: 0.7062
# Epoch 20/300
# 200/200 [==============================] - 907s 5s/step - loss: 0.4419 - acc: 0.7812 - val_loss: 0.3659 - val_acc: 0.7205
# Epoch 21/300
# 200/200 [==============================] - 895s 4s/step - loss: 0.4382 - acc: 0.7840 - val_loss: 0.4984 - val_acc: 0.7093
# Epoch 22/300
# 200/200 [==============================] - 910s 5s/step - loss: 0.4262 - acc: 0.7916 - val_loss: 0.6973 - val_acc: 0.7370
# Epoch 23/300
# 200/200 [==============================] - 917s 5s/step - loss: 0.4160 - acc: 0.7948 - val_loss: 0.3937 - val_acc: 0.6927
# Epoch 24/300
# 200/200 [==============================] - 906s 5s/step - loss: 0.4349 - acc: 0.7914 - val_loss: 0.2548 - val_acc: 0.7266
# Epoch 25/300
# 200/200 [==============================] - 900s 4s/step - loss: 0.3918 - acc: 0.8149 - val_loss: 0.3536 - val_acc: 0.6648
# Epoch 26/300
# 200/200 [==============================] - 893s 4s/step - loss: 0.3752 - acc: 0.8237 - val_loss: 0.8210 - val_acc: 0.7451
# Epoch 27/300
# 200/200 [==============================] - 898s 4s/step - loss: 0.3671 - acc: 0.8282 - val_loss: 0.9727 - val_acc: 0.7324
# Epoch 28/300
# 200/200 [==============================] - 882s 4s/step - loss: 0.3571 - acc: 0.8297 - val_loss: 0.6826 - val_acc: 0.7372
# Epoch 29/300
# 200/200 [==============================] - 871s 4s/step - loss: 0.3420 - acc: 0.8447 - val_loss: 0.7696 - val_acc: 0.7458
# Epoch 30/300
# 200/200 [==============================] - 866s 4s/step - loss: 0.3399 - acc: 0.8480 - val_loss: 0.7993 - val_acc: 0.7634
# Epoch 31/300
# 200/200 [==============================] - 895s 4s/step - loss: 0.3277 - acc: 0.8521 - val_loss: 0.4507 - val_acc: 0.7301
# Epoch 32/300
# 200/200 [==============================] - 865s 4s/step - loss: 0.3166 - acc: 0.8568 - val_loss: 0.7435 - val_acc: 0.7746
# Epoch 33/300
# 200/200 [==============================] - 863s 4s/step - loss: 0.3105 - acc: 0.8587 - val_loss: 0.2591 - val_acc: 0.7689
# Epoch 34/300
# 200/200 [==============================] - 858s 4s/step - loss: 0.2983 - acc: 0.8698 - val_loss: 0.8102 - val_acc: 0.7632
# Epoch 35/300
# 200/200 [==============================] - 876s 4s/step - loss: 0.2899 - acc: 0.8776 - val_loss: 0.3918 - val_acc: 0.7667
# Epoch 36/300
# 200/200 [==============================] - 849s 4s/step - loss: 0.2784 - acc: 0.8788 - val_loss: 0.4213 - val_acc: 0.8058
# Epoch 37/300
# 200/200 [==============================] - 844s 4s/step - loss: 0.2821 - acc: 0.8775 - val_loss: 0.9089 - val_acc: 0.7258
# Epoch 38/300
# 200/200 [==============================] - 838s 4s/step - loss: 0.2677 - acc: 0.8873 - val_loss: 0.5959 - val_acc: 0.7432
# Epoch 39/300
# 200/200 [==============================] - 859s 4s/step - loss: 0.2680 - acc: 0.8887 - val_loss: 2.7209 - val_acc: 0.5478
# Epoch 40/300
# 200/200 [==============================] - 837s 4s/step - loss: 0.2784 - acc: 0.8814 - val_loss: 0.9130 - val_acc: 0.7296
# Epoch 41/300
# 200/200 [==============================] - 849s 4s/step - loss: 0.2548 - acc: 0.8928 - val_loss: 0.7492 - val_acc: 0.7367
# Epoch 42/300
# 200/200 [==============================] - 836s 4s/step - loss: 0.2513 - acc: 0.8953 - val_loss: 0.5774 - val_acc: 0.8024
# Epoch 43/300
# 200/200 [==============================] - 857s 4s/step - loss: 0.2445 - acc: 0.8983 - val_loss: 0.3704 - val_acc: 0.7984
# Epoch 44/300
# 200/200 [==============================] - 842s 4s/step - loss: 0.2567 - acc: 0.8936 - val_loss: 0.1061 - val_acc: 0.8106
# Epoch 45/300
# 200/200 [==============================] - 836s 4s/step - loss: 0.2354 - acc: 0.9017 - val_loss: 0.2164 - val_acc: 0.8228
# Epoch 46/300
# 200/200 [==============================] - 839s 4s/step - loss: 0.2037 - acc: 0.9185 - val_loss: 0.7700 - val_acc: 0.7967
# Epoch 47/300
# 200/200 [==============================] - 843s 4s/step - loss: 0.2121 - acc: 0.9139 - val_loss: 0.5945 - val_acc: 0.7536
# Epoch 48/300
# 200/200 [==============================] - 850s 4s/step - loss: 0.2076 - acc: 0.9129 - val_loss: 1.1685 - val_acc: 0.7628
# Epoch 49/300
# 200/200 [==============================] - 833s 4s/step - loss: 0.2082 - acc: 0.9146 - val_loss: 0.0860 - val_acc: 0.7981
# Epoch 50/300
# 200/200 [==============================] - 840s 4s/step - loss: 0.2105 - acc: 0.9151 - val_loss: 0.7451 - val_acc: 0.7866
# Epoch 51/300
# 200/200 [==============================] - 831s 4s/step - loss: 0.1995 - acc: 0.9196 - val_loss: 0.4342 - val_acc: 0.8012
# Epoch 52/300
# 200/200 [==============================] - 860s 4s/step - loss: 0.1952 - acc: 0.9219 - val_loss: 0.8276 - val_acc: 0.7488
# Epoch 53/300
# 200/200 [==============================] - 827s 4s/step - loss: 0.2025 - acc: 0.9211 - val_loss: 0.0981 - val_acc: 0.7935
# Epoch 54/300
# 200/200 [==============================] - 837s 4s/step - loss: 0.1894 - acc: 0.9226 - val_loss: 0.5714 - val_acc: 0.8146
# Epoch 55/300
# 200/200 [==============================] - 823s 4s/step - loss: 0.1946 - acc: 0.9238 - val_loss: 0.6926 - val_acc: 0.7703
# Epoch 56/300
# 200/200 [==============================] - 859s 4s/step - loss: 0.1818 - acc: 0.9246 - val_loss: 2.5098 - val_acc: 0.6674
# Epoch 57/300
# 200/200 [==============================] - 823s 4s/step - loss: 0.1896 - acc: 0.9258 - val_loss: 0.5968 - val_acc: 0.8083
# Epoch 58/300
# 200/200 [==============================] - 829s 4s/step - loss: 0.1942 - acc: 0.9230 - val_loss: 0.1189 - val_acc: 0.8236
# Epoch 59/300
# 200/200 [==============================] - 833s 4s/step - loss: 0.1860 - acc: 0.9260 - val_loss: 0.5444 - val_acc: 0.8091
# Epoch 60/300
# 200/200 [==============================] - 850s 4s/step - loss: 0.1678 - acc: 0.9347 - val_loss: 0.2639 - val_acc: 0.8058
# Epoch 61/300
# 200/200 [==============================] - 846s 4s/step - loss: 0.1682 - acc: 0.9366 - val_loss: 0.2109 - val_acc: 0.8212
# Epoch 62/300
# 200/200 [==============================] - 828s 4s/step - loss: 0.1667 - acc: 0.9338 - val_loss: 0.1691 - val_acc: 0.8379
# Epoch 63/300
# 200/200 [==============================] - 827s 4s/step - loss: 0.1663 - acc: 0.9364 - val_loss: 0.0831 - val_acc: 0.7764
# Epoch 64/300
# 200/200 [==============================] - 830s 4s/step - loss: 0.1696 - acc: 0.9332 - val_loss: 0.1769 - val_acc: 0.8122
# Epoch 65/300
# 200/200 [==============================] - 847s 4s/step - loss: 0.1660 - acc: 0.9361 - val_loss: 0.2460 - val_acc: 0.7935
# Epoch 66/300
# 200/200 [==============================] - 831s 4s/step - loss: 0.1557 - acc: 0.9420 - val_loss: 0.8883 - val_acc: 0.8157
# Epoch 67/300
# 200/200 [==============================] - 830s 4s/step - loss: 0.1750 - acc: 0.9334 - val_loss: 0.2724 - val_acc: 0.7879
# Epoch 68/300
# 200/200 [==============================] - 829s 4s/step - loss: 0.1630 - acc: 0.9360 - val_loss: 0.5069 - val_acc: 0.8187
# Epoch 69/300
# 200/200 [==============================] - 848s 4s/step - loss: 0.1445 - acc: 0.9437 - val_loss: 0.3340 - val_acc: 0.8432
# Epoch 70/300
# 200/200 [==============================] - 826s 4s/step - loss: 0.1554 - acc: 0.9446 - val_loss: 1.1748 - val_acc: 0.7562
# Epoch 71/300
# 200/200 [==============================] - 842s 4s/step - loss: 0.1443 - acc: 0.9443 - val_loss: 0.2978 - val_acc: 0.8303
# Epoch 72/300
# 200/200 [==============================] - 836s 4s/step - loss: 0.1533 - acc: 0.9418 - val_loss: 0.3266 - val_acc: 0.7782
# Epoch 73/300
# 200/200 [==============================] - 870s 4s/step - loss: 0.1431 - acc: 0.9446 - val_loss: 0.1068 - val_acc: 0.7121
# Epoch 74/300
# 200/200 [==============================] - 875s 4s/step - loss: 0.1394 - acc: 0.9443 - val_loss: 0.1302 - val_acc: 0.7381
# Epoch 75/300
# 200/200 [==============================] - 870s 4s/step - loss: 0.1400 - acc: 0.9471 - val_loss: 0.7291 - val_acc: 0.8033
# Epoch 76/300
# 200/200 [==============================] - 865s 4s/step - loss: 0.1316 - acc: 0.9522 - val_loss: 1.0871 - val_acc: 0.7373
# Epoch 77/300
# 200/200 [==============================] - 884s 4s/step - loss: 0.1626 - acc: 0.9388 - val_loss: 0.7430 - val_acc: 0.7666
# Epoch 78/300
# 200/200 [==============================] - 880s 4s/step - loss: 0.1457 - acc: 0.9448 - val_loss: 0.4262 - val_acc: 0.8402
# Epoch 79/300
# 200/200 [==============================] - 897s 4s/step - loss: 0.1269 - acc: 0.9520 - val_loss: 0.9814 - val_acc: 0.7896
# Epoch 80/300
# 200/200 [==============================] - 906s 5s/step - loss: 0.1630 - acc: 0.9359 - val_loss: 0.4171 - val_acc: 0.7989
# Epoch 81/300
# 200/200 [==============================] - 925s 5s/step - loss: 0.1404 - acc: 0.9469 - val_loss: 0.5136 - val_acc: 0.8348
# Epoch 82/300
# 200/200 [==============================] - 906s 5s/step - loss: 0.1259 - acc: 0.9509 - val_loss: 0.5707 - val_acc: 0.8588
# Epoch 83/300
# 200/200 [==============================] - 907s 5s/step - loss: 0.1296 - acc: 0.9521 - val_loss: 0.3818 - val_acc: 0.8602
# Epoch 84/300
# 200/200 [==============================] - 894s 4s/step - loss: 0.1356 - acc: 0.9516 - val_loss: 0.1036 - val_acc: 0.8121
# Epoch 85/300
# 200/200 [==============================] - 910s 5s/step - loss: 0.1066 - acc: 0.9620 - val_loss: 0.2921 - val_acc: 0.8661
# Epoch 86/300
# 200/200 [==============================] - 890s 4s/step - loss: 0.1000 - acc: 0.9629 - val_loss: 0.8173 - val_acc: 0.8247
# Epoch 87/300
# 200/200 [==============================] - 878s 4s/step - loss: 0.1009 - acc: 0.9639 - val_loss: 0.9354 - val_acc: 0.8282
# Epoch 88/300
# 200/200 [==============================] - 881s 4s/step - loss: 0.1110 - acc: 0.9578 - val_loss: 0.8190 - val_acc: 0.8368
# Epoch 89/300
# 200/200 [==============================] - 916s 5s/step - loss: 0.1093 - acc: 0.9624 - val_loss: 0.7505 - val_acc: 0.7674
# Epoch 90/300
# 200/200 [==============================] - 902s 5s/step - loss: 0.1013 - acc: 0.9628 - val_loss: 0.6330 - val_acc: 0.8134
# Epoch 91/300
# 200/200 [==============================] - 902s 5s/step - loss: 0.1185 - acc: 0.9583 - val_loss: 0.5720 - val_acc: 0.8526
# Epoch 92/300
# 200/200 [==============================] - 911s 5s/step - loss: 0.0976 - acc: 0.9646 - val_loss: 0.8843 - val_acc: 0.8413
# Epoch 93/300
# 200/200 [==============================] - 932s 5s/step - loss: 0.1002 - acc: 0.9628 - val_loss: 0.9230 - val_acc: 0.7974
# Epoch 94/300
# 200/200 [==============================] - 938s 5s/step - loss: 0.1004 - acc: 0.9641 - val_loss: 0.9619 - val_acc: 0.8198
# Epoch 95/300
# 200/200 [==============================] - 915s 5s/step - loss: 0.0954 - acc: 0.9656 - val_loss: 0.8873 - val_acc: 0.8337
# Epoch 96/300
# 200/200 [==============================] - 921s 5s/step - loss: 0.1054 - acc: 0.9628 - val_loss: 0.3142 - val_acc: 0.8571
# Epoch 97/300
# 200/200 [==============================] - 943s 5s/step - loss: 0.0990 - acc: 0.9644 - val_loss: 0.2581 - val_acc: 0.8607
# Epoch 98/300
# 200/200 [==============================] - 921s 5s/step - loss: 0.0969 - acc: 0.9634 - val_loss: 0.5135 - val_acc: 0.8626
# Epoch 99/300
# 200/200 [==============================] - 926s 5s/step - loss: 0.0865 - acc: 0.9693 - val_loss: 0.5507 - val_acc: 0.8313
# Epoch 100/300
# 200/200 [==============================] - 935s 5s/step - loss: 0.0919 - acc: 0.9666 - val_loss: 0.5156 - val_acc: 0.8393
# Epoch 101/300
# 200/200 [==============================] - 954s 5s/step - loss: 0.0924 - acc: 0.9665 - val_loss: 1.0238 - val_acc: 0.8489
# Epoch 102/300
# 200/200 [==============================] - 916s 5s/step - loss: 0.0940 - acc: 0.9654 - val_loss: 0.5302 - val_acc: 0.8426
# Epoch 103/300
# 200/200 [==============================] - 928s 5s/step - loss: 0.0958 - acc: 0.9662 - val_loss: 0.4501 - val_acc: 0.8523
# Epoch 104/300
# 200/200 [==============================] - 907s 5s/step - loss: 0.0944 - acc: 0.9665 - val_loss: 0.5789 - val_acc: 0.8499
# Epoch 105/300
# 200/200 [==============================] - 929s 5s/step - loss: 0.0806 - acc: 0.9711 - val_loss: 0.3990 - val_acc: 0.8625
# Epoch 106/300
# 200/200 [==============================] - 922s 5s/step - loss: 0.0775 - acc: 0.9716 - val_loss: 0.3599 - val_acc: 0.8566
# Epoch 107/300
# 200/200 [==============================] - 922s 5s/step - loss: 0.0741 - acc: 0.9729 - val_loss: 0.1128 - val_acc: 0.8406
# Epoch 108/300
# 200/200 [==============================] - 929s 5s/step - loss: 0.0836 - acc: 0.9721 - val_loss: 0.9367 - val_acc: 0.8468
# Epoch 109/300
# 200/200 [==============================] - 933s 5s/step - loss: 0.0848 - acc: 0.9675 - val_loss: 0.6344 - val_acc: 0.8666
# Epoch 110/300
# 200/200 [==============================] - 891s 4s/step - loss: 0.0813 - acc: 0.9719 - val_loss: 0.5705 - val_acc: 0.8564
# Epoch 111/300
# 200/200 [==============================] - 887s 4s/step - loss: 0.0776 - acc: 0.9712 - val_loss: 0.7969 - val_acc: 0.8467
# Epoch 112/300
# 200/200 [==============================] - 872s 4s/step - loss: 0.0672 - acc: 0.9743 - val_loss: 0.5085 - val_acc: 0.8627
# Epoch 113/300
# 200/200 [==============================] - 887s 4s/step - loss: 0.0749 - acc: 0.9724 - val_loss: 0.8959 - val_acc: 0.8352
# Epoch 114/300
# 200/200 [==============================] - 870s 4s/step - loss: 0.0740 - acc: 0.9743 - val_loss: 0.4645 - val_acc: 0.8753
# Epoch 115/300
# 200/200 [==============================] - 845s 4s/step - loss: 0.0716 - acc: 0.9746 - val_loss: 0.3503 - val_acc: 0.8289
# Epoch 116/300
# 200/200 [==============================] - 850s 4s/step - loss: 0.0736 - acc: 0.9736 - val_loss: 0.7968 - val_acc: 0.8467
# Epoch 117/300
# 200/200 [==============================] - 863s 4s/step - loss: 0.0748 - acc: 0.9736 - val_loss: 0.4383 - val_acc: 0.8547
# Epoch 118/300
# 200/200 [==============================] - 859s 4s/step - loss: 0.0696 - acc: 0.9762 - val_loss: 0.4326 - val_acc: 0.8683
# Epoch 119/300
# 200/200 [==============================] - 861s 4s/step - loss: 0.0580 - acc: 0.9795 - val_loss: 0.5685 - val_acc: 0.8611
# Epoch 120/300
# 200/200 [==============================] - 873s 4s/step - loss: 0.0542 - acc: 0.9814 - val_loss: 0.5802 - val_acc: 0.8814
# Epoch 121/300
# 200/200 [==============================] - 880s 4s/step - loss: 0.0667 - acc: 0.9758 - val_loss: 0.6593 - val_acc: 0.8682
# Epoch 122/300
# 200/200 [==============================] - 849s 4s/step - loss: 0.0687 - acc: 0.9766 - val_loss: 0.3863 - val_acc: 0.8393
# Epoch 123/300
# 200/200 [==============================] - 847s 4s/step - loss: 0.0654 - acc: 0.9798 - val_loss: 0.9459 - val_acc: 0.8296
# Epoch 124/300
# 200/200 [==============================] - 847s 4s/step - loss: 0.0643 - acc: 0.9776 - val_loss: 0.5304 - val_acc: 0.8678
# Epoch 125/300
# 200/200 [==============================] - 854s 4s/step - loss: 0.0622 - acc: 0.9774 - val_loss: 0.2279 - val_acc: 0.8702
# Epoch 126/300
# 200/200 [==============================] - 849s 4s/step - loss: 0.0562 - acc: 0.9816 - val_loss: 0.3243 - val_acc: 0.8791
# Epoch 127/300
# 200/200 [==============================] - 832s 4s/step - loss: 0.0543 - acc: 0.9815 - val_loss: 0.5070 - val_acc: 0.8557
# Epoch 128/300
# 200/200 [==============================] - 838s 4s/step - loss: 0.0520 - acc: 0.9820 - val_loss: 0.2528 - val_acc: 0.8721
# Epoch 129/300
# 200/200 [==============================] - 877s 4s/step - loss: 0.0501 - acc: 0.9819 - val_loss: 0.4265 - val_acc: 0.8794
# Epoch 130/300
# 200/200 [==============================] - 855s 4s/step - loss: 0.0585 - acc: 0.9817 - val_loss: 0.5477 - val_acc: 0.8717
# Epoch 131/300
# 200/200 [==============================] - 795s 4s/step - loss: 0.0542 - acc: 0.9819 - val_loss: 0.4786 - val_acc: 0.8693
# Epoch 132/300
# 200/200 [==============================] - 262s 1s/step - loss: 0.0500 - acc: 0.9844 - val_loss: 0.4463 - val_acc: 0.8671
# Epoch 133/300
# 200/200 [==============================] - 266s 1s/step - loss: 0.0537 - acc: 0.9815 - val_loss: 0.5858 - val_acc: 0.8673
# Epoch 134/300
# 200/200 [==============================] - 255s 1s/step - loss: 0.0574 - acc: 0.9780 - val_loss: 0.4418 - val_acc: 0.8646
# Epoch 135/300
# 200/200 [==============================] - 255s 1s/step - loss: 0.0505 - acc: 0.9822 - val_loss: 0.6210 - val_acc: 0.8731
# Epoch 136/300
# 200/200 [==============================] - 257s 1s/step - loss: 0.0507 - acc: 0.9835 - val_loss: 0.5298 - val_acc: 0.8717
# Epoch 137/300
# 200/200 [==============================] - 250s 1s/step - loss: 0.0533 - acc: 0.9823 - val_loss: 0.3912 - val_acc: 0.8778
# Epoch 138/300
# 200/200 [==============================] - 256s 1s/step - loss: 0.0478 - acc: 0.9839 - val_loss: 0.6079 - val_acc: 0.8749
# Epoch 139/300
# 200/200 [==============================] - 250s 1s/step - loss: 0.0496 - acc: 0.9836 - val_loss: 0.6100 - val_acc: 0.8753
# Epoch 140/300
# 200/200 [==============================] - 274s 1s/step - loss: 0.0533 - acc: 0.9807 - val_loss: 0.5912 - val_acc: 0.8769
# Epoch 141/300
# 200/200 [==============================] - 250s 1s/step - loss: 0.0464 - acc: 0.9835 - val_loss: 0.5230 - val_acc: 0.8845
# Epoch 142/300
# 200/200 [==============================] - 253s 1s/step - loss: 0.0469 - acc: 0.9834 - val_loss: 0.5520 - val_acc: 0.8777
# Epoch 143/300
# 200/200 [==============================] - 255s 1s/step - loss: 0.0456 - acc: 0.9846 - val_loss: 0.3803 - val_acc: 0.8808
# Epoch 144/300
# 200/200 [==============================] - 260s 1s/step - loss: 0.0521 - acc: 0.9824 - val_loss: 0.3254 - val_acc: 0.8813
# Epoch 145/300
# 200/200 [==============================] - 252s 1s/step - loss: 0.0431 - acc: 0.9847 - val_loss: 0.6426 - val_acc: 0.8612
# Epoch 146/300
# 200/200 [==============================] - 252s 1s/step - loss: 0.0502 - acc: 0.9830 - val_loss: 0.1274 - val_acc: 0.8676
# Epoch 147/300
# 200/200 [==============================] - 252s 1s/step - loss: 0.0476 - acc: 0.9838 - val_loss: 0.3528 - val_acc: 0.8812
# Epoch 148/300
# 200/200 [==============================] - 256s 1s/step - loss: 0.0452 - acc: 0.9841 - val_loss: 0.3992 - val_acc: 0.8750
# Epoch 149/300
# 200/200 [==============================] - 257s 1s/step - loss: 0.0473 - acc: 0.9840 - val_loss: 0.4673 - val_acc: 0.8708
# Epoch 150/300
# 200/200 [==============================] - 281s 1s/step - loss: 0.0448 - acc: 0.9852 - val_loss: 0.4064 - val_acc: 0.8659
# Epoch 151/300
# 200/200 [==============================] - 262s 1s/step - loss: 0.0454 - acc: 0.9855 - val_loss: 0.5099 - val_acc: 0.8800
# Epoch 152/300
# 200/200 [==============================] - 276s 1s/step - loss: 0.0458 - acc: 0.9856 - val_loss: 0.6552 - val_acc: 0.8726
# Epoch 153/300
# 200/200 [==============================] - 309s 2s/step - loss: 0.0489 - acc: 0.9837 - val_loss: 0.3958 - val_acc: 0.8839
# Epoch 154/300
# 200/200 [==============================] - 346s 2s/step - loss: 0.0475 - acc: 0.9837 - val_loss: 0.5130 - val_acc: 0.8778
# Epoch 155/300
# 200/200 [==============================] - 354s 2s/step - loss: 0.0450 - acc: 0.9840 - val_loss: 0.4665 - val_acc: 0.8837
# Epoch 156/300
# 200/200 [==============================] - 652s 3s/step - loss: 0.0426 - acc: 0.9863 - val_loss: 0.6316 - val_acc: 0.8804
# Epoch 157/300
# 200/200 [==============================] - 332s 2s/step - loss: 0.0452 - acc: 0.9846 - val_loss: 0.4220 - val_acc: 0.8854
# Epoch 158/300
# 200/200 [==============================] - 335s 2s/step - loss: 0.0424 - acc: 0.9851 - val_loss: 0.2267 - val_acc: 0.8603
# Epoch 159/300
# 200/200 [==============================] - 690s 3s/step - loss: 0.0388 - acc: 0.9865 - val_loss: 0.5620 - val_acc: 0.8817
# Epoch 160/300
# 200/200 [==============================] - 273s 1s/step - loss: 0.0423 - acc: 0.9849 - val_loss: 0.4298 - val_acc: 0.8822
# Epoch 161/300
# 200/200 [==============================] - 270s 1s/step - loss: 0.0433 - acc: 0.9863 - val_loss: 0.5553 - val_acc: 0.8829
# Epoch 162/300
# 145/200 [====================>.........] - ETA: 31s - loss: 0.0398 - acc: 0.9862
# C:\ProgramData\Anaconda3\lib\site-packages\keras\utils\data_utils.py:616: UserWarning: The input 7 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# 200/200 [==============================] - 342s 2s/step - loss: 0.0395 - acc: 0.9860 - val_loss: 0.5028 - val_acc: 0.8859
# Epoch 163/300
# 200/200 [==============================] - 340s 2s/step - loss: 0.0425 - acc: 0.9872 - val_loss: 0.6315 - val_acc: 0.8804
# Epoch 164/300
# 200/200 [==============================] - 687s 3s/step - loss: 0.0438 - acc: 0.9847 - val_loss: 0.6168 - val_acc: 0.8806
# Epoch 165/300
# 200/200 [==============================] - 677s 3s/step - loss: 0.0370 - acc: 0.9885 - val_loss: 0.5296 - val_acc: 0.8870
# Epoch 166/300
# 200/200 [==============================] - 756s 4s/step - loss: 0.0366 - acc: 0.9880 - val_loss: 0.6831 - val_acc: 0.8842
# Epoch 167/300
# 200/200 [==============================] - 387s 2s/step - loss: 0.0387 - acc: 0.9864 - val_loss: 0.6240 - val_acc: 0.8809
# Epoch 168/300
# 200/200 [==============================] - 556s 3s/step - loss: 0.0427 - acc: 0.9850 - val_loss: 0.4615 - val_acc: 0.8829
# Epoch 169/300
# 200/200 [==============================] - 395s 2s/step - loss: 0.0378 - acc: 0.9864 - val_loss: 0.5141 - val_acc: 0.8865
# Epoch 170/300
# 200/200 [==============================] - 547s 3s/step - loss: 0.0396 - acc: 0.9861 - val_loss: 0.5703 - val_acc: 0.8882
# Epoch 171/300
# 200/200 [==============================] - 254s 1s/step - loss: 0.0392 - acc: 0.9858 - val_loss: 0.4664 - val_acc: 0.8839
# Epoch 172/300
# 200/200 [==============================] - 249s 1s/step - loss: 0.0388 - acc: 0.9869 - val_loss: 0.5848 - val_acc: 0.8876
# Epoch 173/300
# 200/200 [==============================] - 246s 1s/step - loss: 0.0399 - acc: 0.9853 - val_loss: 0.4894 - val_acc: 0.8874
# Epoch 174/300
# 200/200 [==============================] - 257s 1s/step - loss: 0.0405 - acc: 0.9863 - val_loss: 0.5896 - val_acc: 0.8824
# Epoch 175/300
# 200/200 [==============================] - 253s 1s/step - loss: 0.0394 - acc: 0.9853 - val_loss: 0.4647 - val_acc: 0.8862
# Epoch 176/300
# 200/200 [==============================] - 259s 1s/step - loss: 0.0425 - acc: 0.9847 - val_loss: 0.5807 - val_acc: 0.8852
# Epoch 177/300
# 200/200 [==============================] - 259s 1s/step - loss: 0.0362 - acc: 0.9876 - val_loss: 0.5429 - val_acc: 0.8878
# Epoch 178/300
# 200/200 [==============================] - 246s 1s/step - loss: 0.0386 - acc: 0.9861 - val_loss: 0.5532 - val_acc: 0.8893
# Epoch 179/300
# 200/200 [==============================] - 253s 1s/step - loss: 0.0399 - acc: 0.9863 - val_loss: 0.5062 - val_acc: 0.8892
# Epoch 180/300
# 200/200 [==============================] - 250s 1s/step - loss: 0.0395 - acc: 0.9865 - val_loss: 0.5085 - val_acc: 0.8888
# Epoch 181/300
# 200/200 [==============================] - 247s 1s/step - loss: 0.0381 - acc: 0.9874 - val_loss: 0.5589 - val_acc: 0.8859
# Epoch 182/300
# 200/200 [==============================] - 271s 1s/step - loss: 0.0348 - acc: 0.9876 - val_loss: 0.4565 - val_acc: 0.8882
# Epoch 183/300
# 200/200 [==============================] - 256s 1s/step - loss: 0.0372 - acc: 0.9873 - val_loss: 0.5393 - val_acc: 0.8872
# Epoch 184/300
# 200/200 [==============================] - 256s 1s/step - loss: 0.0400 - acc: 0.9867 - val_loss: 0.5522 - val_acc: 0.8879
# Epoch 185/300
# 200/200 [==============================] - 253s 1s/step - loss: 0.0397 - acc: 0.9864 - val_loss: 0.4789 - val_acc: 0.8881
# Epoch 186/300
# 200/200 [==============================] - 243s 1s/step - loss: 0.0368 - acc: 0.9871 - val_loss: 0.5576 - val_acc: 0.8883
# Epoch 187/300
# 200/200 [==============================] - 255s 1s/step - loss: 0.0391 - acc: 0.9860 - val_loss: 0.5289 - val_acc: 0.8901
# Epoch 188/300
# 200/200 [==============================] - 249s 1s/step - loss: 0.0353 - acc: 0.9877 - val_loss: 0.5940 - val_acc: 0.8853
# Epoch 189/300
# 200/200 [==============================] - 246s 1s/step - loss: 0.0426 - acc: 0.9850 - val_loss: 0.4892 - val_acc: 0.8900
# Epoch 190/300
# 200/200 [==============================] - 257s 1s/step - loss: 0.0357 - acc: 0.9888 - val_loss: 0.5596 - val_acc: 0.8856
# Epoch 191/300
# 200/200 [==============================] - 242s 1s/step - loss: 0.0372 - acc: 0.9862 - val_loss: 0.5560 - val_acc: 0.8863
# Epoch 192/300
# 200/200 [==============================] - 255s 1s/step - loss: 0.0365 - acc: 0.9876 - val_loss: 0.5386 - val_acc: 0.8892
# Epoch 193/300
# 200/200 [==============================] - 253s 1s/step - loss: 0.0368 - acc: 0.9877 - val_loss: 0.5336 - val_acc: 0.8890
# Epoch 194/300
# 200/200 [==============================] - 247s 1s/step - loss: 0.0341 - acc: 0.9889 - val_loss: 0.5665 - val_acc: 0.8879
# Epoch 195/300
# 200/200 [==============================] - 256s 1s/step - loss: 0.0373 - acc: 0.9872 - val_loss: 0.5797 - val_acc: 0.8874
# Epoch 196/300
# 200/200 [==============================] - 260s 1s/step - loss: 0.0326 - acc: 0.9891 - val_loss: 0.5727 - val_acc: 0.8848
# Epoch 197/300
# 200/200 [==============================] - 259s 1s/step - loss: 0.0355 - acc: 0.9884 - val_loss: 0.5094 - val_acc: 0.8889
# Epoch 198/300
# 200/200 [==============================] - 259s 1s/step - loss: 0.0351 - acc: 0.9887 - val_loss: 0.5354 - val_acc: 0.8880
# Epoch 199/300
# 200/200 [==============================] - 247s 1s/step - loss: 0.0367 - acc: 0.9872 - val_loss: 0.5360 - val_acc: 0.8872
# Epoch 200/300
# 200/200 [==============================] - 259s 1s/step - loss: 0.0366 - acc: 0.9874 - val_loss: 0.5226 - val_acc: 0.8874
# Epoch 201/300
# 200/200 [==============================] - 251s 1s/step - loss: 0.0358 - acc: 0.9873 - val_loss: 0.5353 - val_acc: 0.8889
# Epoch 202/300
# 200/200 [==============================] - 245s 1s/step - loss: 0.0396 - acc: 0.9859 - val_loss: 0.4997 - val_acc: 0.8896
# Epoch 203/300
# 200/200 [==============================] - 256s 1s/step - loss: 0.0378 - acc: 0.9867 - val_loss: 0.5117 - val_acc: 0.8893
# Epoch 204/300
# 200/200 [==============================] - 247s 1s/step - loss: 0.0366 - acc: 0.9878 - val_loss: 0.4908 - val_acc: 0.8898
# Epoch 205/300
# 200/200 [==============================] - 247s 1s/step - loss: 0.0364 - acc: 0.9887 - val_loss: 0.5257 - val_acc: 0.8887
# Epoch 206/300
# 200/200 [==============================] - 254s 1s/step - loss: 0.0331 - acc: 0.9886 - val_loss: 0.5435 - val_acc: 0.8873
# Epoch 207/300
# 200/200 [==============================] - 253s 1s/step - loss: 0.0384 - acc: 0.9864 - val_loss: 0.5097 - val_acc: 0.8891
# Epoch 208/300
# 200/200 [==============================] - 263s 1s/step - loss: 0.0361 - acc: 0.9872 - val_loss: 0.5033 - val_acc: 0.8891
# Epoch 209/300
# 200/200 [==============================] - 267s 1s/step - loss: 0.0364 - acc: 0.9877 - val_loss: 0.5146 - val_acc: 0.8886
# Epoch 210/300
# 200/200 [==============================] - 252s 1s/step - loss: 0.0340 - acc: 0.9879 - val_loss: 0.5061 - val_acc: 0.8890
# Epoch 211/300
# 200/200 [==============================] - 274s 1s/step - loss: 0.0352 - acc: 0.9870 - val_loss: 0.5154 - val_acc: 0.8879
# Epoch 212/300
# 200/200 [==============================] - 249s 1s/step - loss: 0.0345 - acc: 0.9884 - val_loss: 0.4832 - val_acc: 0.8881
# Epoch 213/300
# 200/200 [==============================] - 246s 1s/step - loss: 0.0330 - acc: 0.9881 - val_loss: 0.4952 - val_acc: 0.8882
# Epoch 214/300
# 200/200 [==============================] - 255s 1s/step - loss: 0.0325 - acc: 0.9893 - val_loss: 0.5025 - val_acc: 0.8890
# Epoch 215/300
# 200/200 [==============================] - 245s 1s/step - loss: 0.0360 - acc: 0.9877 - val_loss: 0.5015 - val_acc: 0.8889
# Epoch 216/300
# 200/200 [==============================] - 254s 1s/step - loss: 0.0340 - acc: 0.9874 - val_loss: 0.5186 - val_acc: 0.8896
# Epoch 217/300
# 200/200 [==============================] - 255s 1s/step - loss: 0.0360 - acc: 0.9865 - val_loss: 0.5253 - val_acc: 0.8879

# %%
output_score50 = []
output_class50 = []
answer_class50 = []
answer_class50_1 =[]

for i in range(len(test50_generator)):
    output50 = model_top.predict_on_batch(test50_generator[i][0])
    output_score50.append(output50)
    answer_class50.append(test50_generator[i][1])
    
output_score50 = np.concatenate(output_score50)
answer_class50 = np.concatenate(answer_class50)

output_class50 = np.argmax(output_score50, axis=1)
answer_class50_1 = np.argmax(answer_class50, axis=1)

print(output_class50)
print(answer_class50_1)
# Out:
# [0 0 0 ... 1 1 1]
# [0 0 0 ... 1 1 1]

# %%
cm50 = confusion_matrix(answer_class50_1, output_class50)
report50 = classification_report(answer_class50_1, output_class50)

recall50 = cm50[0][0] / (cm50[0][0] + cm50[0][1])
fallout50 = cm50[1][0] / (cm50[1][0] + cm50[1][1])

fpr50, tpr50, thresholds50 = roc_curve(answer_class50_1, output_score50[:, 1], pos_label=1.)
eer50 = brentq(lambda x : 1. - x - interp1d(fpr50, tpr50)(x), 0., 1.)
thresh50 = interp1d(fpr50, thresholds50)(eer50)

print(report50)
print(cm50)
print("AUROC: %f" %(roc_auc_score(answer_class50_1, output_score50[:, 1])))
print(thresh50)
print('test_acc: ', len(output_class50[np.equal(output_class50, answer_class50_1)]) / len(output_class50))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.92      0.90     10000
#            1       0.91      0.87      0.89     10000
#
#     accuracy                           0.89     20000
#    macro avg       0.89      0.89      0.89     20000
# weighted avg       0.89      0.89      0.89     20000
#
# [[9180  820]
#  [1333 8667]]
# AUROC: 0.957092
# 0.2383655756721987
# test_acc:  0.89235

# %%
model_top.save('/home/www/fake_detection/model/face2face_squeezenet_ft.h5')
