# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
from keras import backend as K
# os.environ["CUDA_VISIBLE_DEVICES"] = '2'
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)
K.set_session(sess)

from keras.regularizers import l2
from keras.layers import Input, Dense, Flatten, GlobalAveragePooling2D, Activation, Conv2D, MaxPooling2D, BatchNormalization, Lambda, Dropout
from keras.layers import SeparableConv2D, Add, Convolution2D, concatenate, Layer, ReLU, DepthwiseConv2D, Reshape, Multiply, InputSpec
from keras.models import Model, load_model, model_from_json
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam, SGD
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.utils import to_categorical
from sklearn import metrics
from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
from scipy.optimize import brentq
from scipy.interpolate import interp1d
import glob
from PIL import Image
from tqdm import tqdm, trange
import random
from keras.applications import Xception
import cv2
# Out:
# Using TensorFlow backend.

# %%
nb_classes = 2  # number of classes
img_width, img_height = 64, 64  # change based on the shape/structure of your images
batch_size = 32  # try 4, 8, 16, 32, 64, 128, 256 dependent on CPU/GPU memory capacity (powers of 2 values).
nb_epoch = 300  # number of iteration the algorithm gets trained.

# %% [markdown]
# # Dir

# %%
train_dir = '/mnt/a/fakedata/face2face/train'
validation_dir = '/mnt/a/fakedata/face2face/val'
test50_dir = '/mnt/a/fakedata/face2face/test'

# %% [markdown]
# # Xception

# %%
img_input = Input(shape=(img_height, img_width, 3))

# layer 1 #
x = Conv2D(filters=32, kernel_size=(3, 3), strides=2, padding='valid', use_bias=False)(img_input)
x = BatchNormalization()(x)
x = Activation('relu')(x)

# layer 2 #
x = Conv2D(filters=64, kernel_size=(3, 3), padding='valid', use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

# skip layer 1 #
res = Conv2D(filters=128, kernel_size=(1, 1), strides=2, padding='same', use_bias=False)(x)
res = BatchNormalization()(res)

# layer 3 #
x = SeparableConv2D(filters=128, kernel_size=(3, 3), strides=1, padding='same', use_bias=False)(x)
x = BatchNormalization()(x)

# layer 4 #
x = Activation('relu')(x)
x = SeparableConv2D(filters=128, kernel_size=(3,3), strides=1, padding='same', use_bias=False)(x)
x = MaxPooling2D(pool_size=(3, 3), strides=2, padding='same')(x)
x = Add()([x, res])

# skip layer 2 #
res = Conv2D(filters=256, kernel_size=(1, 1), strides=2, padding='same', use_bias=False)(x)
res = BatchNormalization()(res)

# layer 5 #
x = Activation('relu')(x)
x = SeparableConv2D(filters=256, kernel_size=(3, 3), strides=1, padding='same', use_bias=False)(x)
x = BatchNormalization()(x)

# layer 6 #
x = Activation('relu')(x)
x = SeparableConv2D(filters=256, kernel_size=(3,3), strides=1, padding='same', use_bias=False)(x)
x = MaxPooling2D(pool_size=(3, 3), strides=2, padding='same')(x)
x = Add()([x, res])

# skip layer 3 #
res = Conv2D(filters=728, kernel_size=(1, 1), strides=2, padding='same', use_bias=False)(x)
res = BatchNormalization()(res)

# layer 7 #
x = Activation('relu')(x)
x = SeparableConv2D(filters=728, kernel_size=(3, 3), strides=1, padding='same', use_bias=False)(x)
x = BatchNormalization()(x)

# layer 8 #
x = Activation('relu')(x)
x = SeparableConv2D(filters=728, kernel_size=(3,3), strides=1, padding='same', use_bias=False)(x)
x = MaxPooling2D(pool_size=(3, 3), strides=2, padding='same')(x)
x = Add()([x, res])

# ======== middle flow ========= #
for i in range(8):
    # layer 9, 10, 11, 12, 13, 14, 15, 16, 17 #
    res = x
    
    x = Activation('relu')(x)
    x = SeparableConv2D(filters=728, kernel_size=(3, 3), strides=1, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    
    x = Activation('relu')(x)
    x = SeparableConv2D(filters=728, kernel_size=(3, 3), strides=1, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)    

    x = Activation('relu')(x)
    x = SeparableConv2D(filters=728, kernel_size=(3, 3), strides=1, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)

    x = Add()([x, res])    

# ======== exit flow ========== #
# skip layer 4 #
res = Conv2D(filters=1024, kernel_size=(1, 1), strides=2, padding='same', use_bias=False)(x)
res = BatchNormalization()(res)

# layer 18 #
x = Activation('relu')(x)
x = SeparableConv2D(filters=728, kernel_size=(3, 3), strides=1, padding='same', use_bias=False)(x)
x = BatchNormalization()(x)

# layer 19 #
x = Activation('relu')(x)
x = SeparableConv2D(filters=1024, kernel_size=(3, 3), strides=1, padding='same', use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(3, 3), strides=2, padding='same')(x)
x = Add()([x, res])

# layer 20 #
x = SeparableConv2D(filters=1536, kernel_size=(3, 3), strides=1, padding='same', use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

# layer 21 #
x = SeparableConv2D(filters=2048, kernel_size=(3, 3), strides=1, padding='same', use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x_gap = GlobalAveragePooling2D()(x)
output = Dense(units=2, activation='softmax')(x_gap)

model = Model(img_input, output)
model.summary()
# Out:
# WARNING:tensorflow:From /home/www/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 31, 31, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 31, 31, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 31, 31, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 29, 29, 64)   18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 29, 29, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 29, 29, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 29, 29, 128)  8768        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 29, 29, 128)  512         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 29, 29, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 29, 29, 128)  17536       activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 15, 15, 128)  8192        activation_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 15, 15, 128)  0           separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 15, 15, 128)  512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 15, 15, 128)  0           max_pooling2d_1[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 15, 15, 128)  0           add_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 15, 15, 256)  33920       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 15, 15, 256)  1024        separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 15, 15, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 15, 15, 256)  67840       activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 8, 8, 256)    32768       add_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 256)    0           separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 256)    1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 8, 8, 256)    0           max_pooling2d_2[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 8, 8, 256)    0           add_2[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 8, 8, 728)    188672      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 8, 728)    2912        separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 8, 8, 728)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_6 (SeparableCo (None, 8, 8, 728)    536536      activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 4, 4, 728)    186368      add_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 728)    0           separable_conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, 4, 728)    2912        conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 4, 4, 728)    0           max_pooling2d_3[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 4, 4, 728)    0           add_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_7 (SeparableCo (None, 4, 4, 728)    536536      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 4, 4, 728)    2912        separable_conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 4, 4, 728)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_8 (SeparableCo (None, 4, 4, 728)    536536      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 4, 4, 728)    2912        separable_conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 4, 4, 728)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_9 (SeparableCo (None, 4, 4, 728)    536536      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 4, 4, 728)    2912        separable_conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 4, 4, 728)    0           batch_normalization_11[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 4, 4, 728)    0           add_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_10 (SeparableC (None, 4, 4, 728)    536536      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 4, 4, 728)    2912        separable_conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 4, 4, 728)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_11 (SeparableC (None, 4, 4, 728)    536536      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 4, 4, 728)    2912        separable_conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 4, 4, 728)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_12 (SeparableC (None, 4, 4, 728)    536536      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 4, 4, 728)    2912        separable_conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 4, 4, 728)    0           batch_normalization_14[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 4, 4, 728)    0           add_5[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_13 (SeparableC (None, 4, 4, 728)    536536      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 4, 4, 728)    2912        separable_conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 4, 4, 728)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_14 (SeparableC (None, 4, 4, 728)    536536      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 4, 4, 728)    2912        separable_conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 4, 4, 728)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_15 (SeparableC (None, 4, 4, 728)    536536      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 4, 4, 728)    2912        separable_conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, 4, 728)    0           batch_normalization_17[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 4, 4, 728)    0           add_6[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_16 (SeparableC (None, 4, 4, 728)    536536      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 4, 4, 728)    2912        separable_conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 4, 4, 728)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_17 (SeparableC (None, 4, 4, 728)    536536      activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 4, 4, 728)    2912        separable_conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 4, 4, 728)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_18 (SeparableC (None, 4, 4, 728)    536536      activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 4, 4, 728)    2912        separable_conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 4, 4, 728)    0           batch_normalization_20[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 4, 4, 728)    0           add_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_19 (SeparableC (None, 4, 4, 728)    536536      activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 4, 4, 728)    2912        separable_conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 4, 4, 728)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_20 (SeparableC (None, 4, 4, 728)    536536      activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 4, 4, 728)    2912        separable_conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 4, 4, 728)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_21 (SeparableC (None, 4, 4, 728)    536536      activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 4, 4, 728)    2912        separable_conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 4, 4, 728)    0           batch_normalization_23[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 4, 4, 728)    0           add_8[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_22 (SeparableC (None, 4, 4, 728)    536536      activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 4, 4, 728)    2912        separable_conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 4, 4, 728)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_23 (SeparableC (None, 4, 4, 728)    536536      activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 4, 4, 728)    2912        separable_conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 4, 4, 728)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_24 (SeparableC (None, 4, 4, 728)    536536      activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 4, 4, 728)    2912        separable_conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 4, 4, 728)    0           batch_normalization_26[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 4, 4, 728)    0           add_9[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_25 (SeparableC (None, 4, 4, 728)    536536      activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 4, 4, 728)    2912        separable_conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 4, 4, 728)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_26 (SeparableC (None, 4, 4, 728)    536536      activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 4, 4, 728)    2912        separable_conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 4, 4, 728)    0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_27 (SeparableC (None, 4, 4, 728)    536536      activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 4, 4, 728)    2912        separable_conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 4, 4, 728)    0           batch_normalization_29[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 4, 4, 728)    0           add_10[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_28 (SeparableC (None, 4, 4, 728)    536536      activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 4, 4, 728)    2912        separable_conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 4, 4, 728)    0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_29 (SeparableC (None, 4, 4, 728)    536536      activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 4, 4, 728)    2912        separable_conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 4, 4, 728)    0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_30 (SeparableC (None, 4, 4, 728)    536536      activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 4, 4, 728)    2912        separable_conv2d_30[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 4, 4, 728)    0           batch_normalization_32[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 4, 4, 728)    0           add_11[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_31 (SeparableC (None, 4, 4, 728)    536536      activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 4, 4, 728)    2912        separable_conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 4, 4, 728)    0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_32 (SeparableC (None, 4, 4, 1024)   752024      activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 4, 4, 1024)   4096        separable_conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 2, 2, 1024)   745472      add_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 2, 2, 1024)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 2, 2, 1024)   4096        conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 2, 2, 1024)   0           max_pooling2d_4[0][0]
#                                                                  batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_33 (SeparableC (None, 2, 2, 1536)   1582080     add_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 2, 2, 1536)   6144        separable_conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 2, 2, 1536)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_34 (SeparableC (None, 2, 2, 2048)   3159552     activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 2, 2, 2048)   8192        separable_conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 2, 2, 2048)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 2048)         0           activation_35[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            4098        global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 20,861,130
# Trainable params: 20,808,826
# Non-trainable params: 52,304
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=Adam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

print(len(model.trainable_weights))
# Out:
# 150

# %%
def bgr(img):
    return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %% [markdown]
# # Data generator

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   preprocessing_function=bgr)

test_datagen = ImageDataGenerator(rescale=1./255,
                                 preprocessing_function=bgr)

train_generator = train_datagen.flow_from_directory(train_dir,
                                                        target_size=(img_height, img_width),
                                                        batch_size=batch_size,
                                                        shuffle=True,
                                                        class_mode='categorical')

validation_generator = train_datagen.flow_from_directory(validation_dir,
                                                        target_size=(img_height, img_width),
                                                        batch_size=batch_size,
                                                        shuffle=False,
                                                        class_mode='categorical')

test50_generator = test_datagen.flow_from_directory(test50_dir,
                                                  target_size=(img_height, img_width),
                                                  batch_size=batch_size,
                                                  shuffle=False,
                                                  class_mode='categorical')
# Out:
# Found 60000 images belonging to 2 classes.
# Found 18000 images belonging to 2 classes.
# Found 20000 images belonging to 2 classes.

# %%
# callback_list = [EarlyStopping(monitor='val_accuracy', patience=10),
#                  ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3)]
# history = model.fit_generator(train_generator,
#                             steps_per_epoch=200,
#                             epochs=100,
#                             validation_data=validation_generator,
#                             validation_steps=len(validation_generator),
#                             callbacks=callback_list)

# %%
# model.save('/home/www/fake_detection/model/face2face_xception2.h5')

# %%
# model = load_model('/home/www/fake_detection/model/face2face_xception2.h5')

# %%
# output = model.predict_generator(test50_generator, steps=len(test50_generator), verbose=1)
# np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
# print(test50_generator.class_indices)
# print(output)

# %%
# output_score50 = []
# output_class50 = []
# answer_class50 = []
# answer_class50_1 =[]

# for i in trange(len(test50_generator)):
#     output50 = model.predict_on_batch(test50_generator[i][0])
#     output_score50.append(output50)
#     answer_class50.append(test50_generator[i][1])
    
# output_score50 = np.concatenate(output_score50)
# answer_class50 = np.concatenate(answer_class50)

# output_class50 = np.argmax(output_score50, axis=1)
# answer_class50_1 = np.argmax(answer_class50, axis=1)

# print(output_class50)
# print(answer_class50_1)

# %%
# cm50 = confusion_matrix(answer_class50_1, output_class50)
# report50 = classification_report(answer_class50_1, output_class50)

# recall50 = cm50[0][0] / (cm50[0][0] + cm50[0][1])
# fallout50 = cm50[1][0] / (cm50[1][0] + cm50[1][1])

# fpr50, tpr50, thresholds50 = roc_curve(answer_class50_1, output_score50[:, 1], pos_label=1.)
# eer50 = brentq(lambda x : 1. - x - interp1d(fpr50, tpr50)(x), 0., 1.)
# thresh50 = interp1d(fpr50, thresholds50)(eer50)

# print(report50)
# print(cm50)
# print("AUROC: %f" %(roc_auc_score(answer_class50_1, output_score50[:, 1])))
# print(thresh50)
# print('test_acc: ', len(output_class50[np.equal(output_class50, answer_class50_1)]) / len(output_class50))

# %%
def cutout(img):
    """
    # Function: RandomCrop (ZeroPadded (4, 4)) + random occulusion image
    # Arguments:
        img: image
    # Returns:
        img
    """
    img = bgr(img)
    height = img.shape[0]
    width = img.shape[1]
    channels = img.shape[2]
    MAX_CUTS = 3 # chance to get more cuts
    MAX_LENGTH_MUTIPLIER = 10 # chance to get larger cuts
    # 16 for cifar10, 8 for cifar100
    
    # Zero-padded (4, 4)
#     img = np.pad(img, ((4,4),(4,4),(0,0)), mode='constant', constant_values=(0))
    
#     # random-crop 64x64
#     dy, dx = height, width
#     x = np.random.randint(0, width - dx + 1)
#     y = np.random.randint(0, height - dy + 1)
#     img = img[y:(y+dy), x:(x+dx)]
    
#     mean norm
#     mean = img.mean(keepdims=True)
#     img -= mean

    img *= 1./255
    
    mask = np.ones((height, width, channels), dtype=np.float32)
    nb_cuts = np.random.randint(0, MAX_CUTS + 1)
    
    # cutout
    for i in range(nb_cuts):
        y = np.random.randint(height)
        x = np.random.randint(width)
        length = 4 * np.random.randint(1, MAX_LENGTH_MUTIPLIER+1)
        
        y1 = np.clip(y-length//2, 0, height)
        y2 = np.clip(y+length//2, 0, height)
        x1 = np.clip(x-length//2, 0, width)
        x2 = np.clip(x+length//2, 0, width)
        
        mask[y1:y2, x1:x2, :] = 0.
    
    img = img * mask
    return img

# %%
class ReLU6(Layer):
    def __init__(self):
        super().__init__(name="ReLU6")
        self.relu6 = ReLU(max_value=6, name="ReLU6")

    def call(self, input):
        return self.relu6(input)


class HardSigmoid(Layer):
    def __init__(self):
        super().__init__()
        self.relu6 = ReLU6()

    def call(self, input):
        return self.relu6(input + 3.0) / 6.0


class HardSwish(Layer):
    def __init__(self):
        super().__init__()
        self.hard_sigmoid = HardSigmoid()

    def call(self, input):
        return input * self.hard_sigmoid(input)
    
class Attention(Layer):
    def __init__(self, ch, **kwargs):
        super(Attention, self).__init__(**kwargs)
        self.channels = ch
        self.filters_f_g = self.channels // 8
        self.filters_h = self.channels

    def build(self, input_shape):
        kernel_shape_f_g = (1, 1) + (self.channels, self.filters_f_g)
        print(kernel_shape_f_g)
        kernel_shape_h = (1, 1) + (self.channels, self.filters_h)

        # Create a trainable weight variable for this layer:
        self.gamma = self.add_weight(name='gamma', shape=[1], initializer='zeros', trainable=True)
        self.kernel_f = self.add_weight(shape=kernel_shape_f_g,
                                        initializer='glorot_uniform',
                                        name='kernel_f')
        self.kernel_g = self.add_weight(shape=kernel_shape_f_g,
                                        initializer='glorot_uniform',
                                        name='kernel_g')
        self.kernel_h = self.add_weight(shape=kernel_shape_h,
                                        initializer='glorot_uniform',
                                        name='kernel_h')
        self.bias_f = self.add_weight(shape=(self.filters_f_g,),
                                      initializer='zeros',
                                      name='bias_F')
        self.bias_g = self.add_weight(shape=(self.filters_f_g,),
                                      initializer='zeros',
                                      name='bias_g')
        self.bias_h = self.add_weight(shape=(self.filters_h,),
                                      initializer='zeros',
                                      name='bias_h')
        super(Attention, self).build(input_shape)
        # Set input spec.
        self.input_spec = InputSpec(ndim=4,
                                    axes={3: input_shape[-1]})
        self.built = True


    def call(self, x):
        def hw_flatten(x):
            return K.reshape(x, shape=[K.shape(x)[0], K.shape(x)[1]*K.shape(x)[2], K.shape(x)[-1]])

        f = K.conv2d(x,
                     kernel=self.kernel_f,
                     strides=(1, 1), padding='same')  # [bs, h, w, c']
        f = K.bias_add(f, self.bias_f)
        g = K.conv2d(x,
                     kernel=self.kernel_g,
                     strides=(1, 1), padding='same')  # [bs, h, w, c']
        g = K.bias_add(g, self.bias_g)
        h = K.conv2d(x,
                     kernel=self.kernel_h,
                     strides=(1, 1), padding='same')  # [bs, h, w, c]
        h = K.bias_add(h, self.bias_h)

        s = tf.matmul(hw_flatten(g), hw_flatten(f), transpose_b=True)  # # [bs, N, N]

        beta = K.softmax(s, axis=-1)  # attention map

        o = K.batch_dot(beta, hw_flatten(h))  # [bs, N, C]

        o = K.reshape(o, shape=K.shape(x))  # [bs, h, w, C]
        x = self.gamma * o + x

        return x

    def compute_output_shape(self, input_shape):
        return input_shape

# %%
ft_dir = '/mnt/a/fakedata/face2face/finetune'
train_gen_aug = ImageDataGenerator(shear_range=0, 
                               zoom_range=0,
                               rotation_range=0.2,
                               width_shift_range=2., 
                               height_shift_range=2.,
                               horizontal_flip=True,
                               zca_whitening=False,
                               fill_mode='nearest',
                               preprocessing_function=cutout)

test_datagen = ImageDataGenerator(rescale=1./255, preprocessing_function=bgr)

ft_gen = train_gen_aug.flow_from_directory(ft_dir,
                                              target_size=(img_height, img_width),
                                              batch_size=batch_size,
                                              shuffle=True,
                                              class_mode='categorical')


validation_generator = test_datagen.flow_from_directory(validation_dir,
                                                        target_size=(img_height, img_width),
                                                        batch_size=batch_size,
                                                        shuffle=False,
                                                        class_mode='categorical')

test50_generator = test_datagen.flow_from_directory(test50_dir,
                                                  target_size=(img_height, img_width),
                                                  batch_size=batch_size,
                                                  shuffle=False,
                                                  class_mode='categorical')
# Out:
# Found 2000 images belonging to 2 classes.
# Found 18000 images belonging to 2 classes.
# Found 20000 images belonging to 2 classes.

# %%
model_ft = load_model('/home/www/fake_detection/model/face2face_xception2.h5')
for i in range(2):
    model_ft.layers.pop()
im_in = Input(shape=(img_width, img_height, 3))

base_model = Model(img_input, x)
base_model.set_weights(model_ft.get_weights())
# for i in range(len(base_model.layers) - 0):
#     base_model.layers[i].trainable = False
    
x1 = base_model(im_in) # (12, 12, 32)
########### Mobilenet block bneck 3x3 (32 --> 128) #################
expand1 = Conv2D(576, kernel_size=1, strides=1, kernel_regularizer=l2(1e-5), use_bias=False)(x1)
expand1 = BatchNormalization()(expand1)
expand1 = HardSwish()(expand1)
dw1 = DepthwiseConv2D(kernel_size=(3,3), strides=(2,2), padding='same', depthwise_regularizer=l2(1e-5), use_bias=False)(expand1)
dw1 = BatchNormalization()(dw1)
se_gap1 = GlobalAveragePooling2D()(dw1)
se_gap1 = Reshape([1, 1, -1])(se_gap1)
se1 = Conv2D(144, kernel_size=1, strides=1, padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(se_gap1)
se1 = Activation('relu')(se1)
se1 = Conv2D(576, kernel_size=1, strides=1, padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(se1)
se1 = HardSigmoid()(se1)
se1 = Multiply()([expand1, se1])
project1 = HardSwish()(se1)
project1 = Conv2D(128, kernel_size=(1, 1), padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(project1)
project1 = BatchNormalization()(project1)

########### Mobilenet block bneck 5x5 (128 --> 128) #################
expand2 = Conv2D(576, kernel_size=1, strides=1, kernel_regularizer=l2(1e-5), use_bias=False)(project1)
expand2 = BatchNormalization()(expand2)
expand2 = HardSwish()(expand2)
dw2 = DepthwiseConv2D(kernel_size=(5,5), strides=(1,1), padding='same', depthwise_regularizer=l2(1e-5), use_bias=False)(expand2)
dw2 = BatchNormalization()(dw2)
se_gap2 = GlobalAveragePooling2D()(dw2)
se_gap2 = Reshape([1, 1, -1])(se_gap2)
se2 = Conv2D(144, kernel_size=1, strides=1, padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(se_gap2)
se2 = Activation('relu')(se2)
se2 = Conv2D(576, kernel_size=1, strides=1, padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(se2)
se2 = HardSigmoid()(se2)
se2 = Multiply()([expand2, se2])
project2 = HardSwish()(se2)
project2 = Conv2D(128, kernel_size=(1, 1), padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(project2)
project2 = BatchNormalization()(project2)
project2 = Add()([project1, project2])

########### Mobilenet block bneck 5x5 (128 --> 128) #################
expand3 = Conv2D(576, kernel_size=1, strides=1, kernel_regularizer=l2(1e-5), use_bias=False)(project2)
expand3 = BatchNormalization()(expand3)
expand3 = HardSwish()(expand3)
dw3 = DepthwiseConv2D(kernel_size=(5,5), strides=(1,1), padding='same', depthwise_regularizer=l2(1e-5), use_bias=False)(expand3)
dw3 = BatchNormalization()(dw3)
se_gap3 = GlobalAveragePooling2D()(dw3)
se_gap3 = Reshape([1, 1, -1])(se_gap3)
se3 = Conv2D(144, kernel_size=1, strides=1, padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(se_gap3)
se3 = Activation('relu')(se3)
se3 = Conv2D(576, kernel_size=1, strides=1, padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(se3)
se3 = HardSigmoid()(se3)
se3 = Multiply()([expand3, se3])
project3 = HardSwish()(se3)
project3 = Conv2D(128, kernel_size=(1, 1), padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(project3)
project3 = BatchNormalization()(project3)
project3 = Add()([project2, project3])

expand4 = Conv2D(576, kernel_size=1, strides=1, kernel_regularizer=l2(1e-5), use_bias=False)(project3)
expand4 = BatchNormalization()(expand4)
expand4 = HardSwish()(expand4)
dw4 = DepthwiseConv2D(kernel_size=(5,5), strides=(1,1), padding='same', depthwise_regularizer=l2(1e-5), use_bias=False)(expand4)
dw4 = BatchNormalization()(dw4)
se_gap4 = GlobalAveragePooling2D()(dw4)
se_gap4 = Reshape([1, 1, -1])(se_gap4)
se4 = Conv2D(144, kernel_size=1, strides=1, padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(se_gap4)
se4 = Activation('relu')(se4)
se4 = Conv2D(576, kernel_size=1, strides=1, padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(se4)
se4 = HardSigmoid()(se4)
se4 = Multiply()([expand4, se4])
project4 = HardSwish()(se4)
project4 = Conv2D(128, kernel_size=(1, 1), padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(project4)
project4 = BatchNormalization()(project4)
project4 = Add()([project3, project4])


########## Classification ##########
x2 = Conv2D(1020, kernel_size=1, strides=1, padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(project4)
x2 = BatchNormalization()(x2)
x2 = HardSwish()(x2)
x2 = GlobalAveragePooling2D()(x2)
x2 = Reshape([1, 1, -1])(x2)


######## Image Attention Model #########
## Block 1 ###
x3 = SeparableConv2D(32, kernel_size=(3, 3), strides=(2,2), padding='same', depthwise_regularizer=l2(1e-5), pointwise_regularizer=l2(1e-5), use_bias=False)(im_in)
x3 = BatchNormalization()(x3)
x3 = HardSwish()(x3)
x3 = Attention(32)(x3)

### Block 2 ###
x4 = SeparableConv2D(128, kernel_size=(3, 3), strides=(2,2), padding='same', depthwise_regularizer=l2(1e-5), pointwise_regularizer=l2(1e-5), use_bias=False)(x3)
x4 = BatchNormalization()(x4)
x4 = HardSwish()(x4)
x4 = Attention(128)(x4)

### Block 3 ###
x5 = SeparableConv2D(256, kernel_size=(3, 3), strides=(2,2), padding='same', depthwise_regularizer=l2(1e-5), pointwise_regularizer=l2(1e-5), use_bias=False)(x4)
x5 = BatchNormalization()(x5)
x5 = HardSwish()(x5)
x5 = Attention(256)(x5)

### final stage ###
x6 = Conv2D(1020, kernel_size=1, strides=1, padding='valid', kernel_regularizer=l2(1e-5), use_bias=False)(x5)
x6 = BatchNormalization()(x6)
x6 = HardSwish()(x6)
x6 = GlobalAveragePooling2D()(x6)
x6 = Reshape([1, 1, -1])(x6)

####### final addition #########

x2 = Add()([x2, x6])
x2 = Conv2D(2, kernel_size=1, strides=1, padding='valid', kernel_regularizer=l2(1e-5))(x2)
x2 = Activation('softmax')(x2)
x2 = Lambda(lambda x: K.squeeze(x, 1))(x2)
x2 = Lambda(lambda x: K.squeeze(x, 1))(x2)

model_top = Model(inputs=im_in, outputs=x2)
model_top.summary()
# Out:
# WARNING:tensorflow:From /home/www/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# (1, 1, 32, 4)
# (1, 1, 128, 16)
# (1, 1, 256, 32)
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# model_2 (Model)                 (None, 2, 2, 2048)   20857032    input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 2, 2, 576)    1179648     model_2[1][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 2, 2, 576)    2304        conv2d_7[0][0]
# __________________________________________________________________________________________________
# hard_swish_1 (HardSwish)        (None, 2, 2, 576)    0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 1, 1, 576)    5184        hard_swish_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 1, 1, 576)    2304        depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 576)          0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 576)    0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 1, 1, 144)    82944       reshape_1[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 1, 1, 144)    0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 1, 1, 576)    82944       activation_36[0][0]
# __________________________________________________________________________________________________
# hard_sigmoid_2 (HardSigmoid)    (None, 1, 1, 576)    0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 2, 2, 576)    0           hard_swish_1[0][0]
#                                                                  hard_sigmoid_2[0][0]
# __________________________________________________________________________________________________
# hard_swish_2 (HardSwish)        (None, 2, 2, 576)    0           multiply_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 2, 2, 128)    73728       hard_swish_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 2, 2, 128)    512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 2, 2, 576)    73728       batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 2, 2, 576)    2304        conv2d_11[0][0]
# __________________________________________________________________________________________________
# hard_swish_3 (HardSwish)        (None, 2, 2, 576)    0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 2, 2, 576)    14400       hard_swish_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 2, 2, 576)    2304        depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 576)          0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 576)    0           global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 1, 1, 144)    82944       reshape_2[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 1, 1, 144)    0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 1, 1, 576)    82944       activation_37[0][0]
# __________________________________________________________________________________________________
# hard_sigmoid_5 (HardSigmoid)    (None, 1, 1, 576)    0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 2, 2, 576)    0           hard_swish_3[0][0]
#                                                                  hard_sigmoid_5[0][0]
# __________________________________________________________________________________________________
# hard_swish_4 (HardSwish)        (None, 2, 2, 576)    0           multiply_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 2, 2, 128)    73728       hard_swish_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 2, 2, 128)    512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 2, 2, 128)    0           batch_normalization_40[0][0]
#                                                                  batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 2, 2, 576)    73728       add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 2, 2, 576)    2304        conv2d_15[0][0]
# __________________________________________________________________________________________________
# hard_swish_5 (HardSwish)        (None, 2, 2, 576)    0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (None, 2, 2, 576)    14400       hard_swish_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 2, 2, 576)    2304        depthwise_conv2d_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 576)          0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 576)    0           global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 1, 1, 144)    82944       reshape_3[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 1, 1, 144)    0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 1, 1, 576)    82944       activation_38[0][0]
# __________________________________________________________________________________________________
# hard_sigmoid_8 (HardSigmoid)    (None, 1, 1, 576)    0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 2, 2, 576)    0           hard_swish_5[0][0]
#                                                                  hard_sigmoid_8[0][0]
# __________________________________________________________________________________________________
# hard_swish_6 (HardSwish)        (None, 2, 2, 576)    0           multiply_3[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 2, 2, 128)    73728       hard_swish_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 2, 2, 128)    512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 2, 2, 128)    0           add_13[0][0]
#                                                                  batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 2, 2, 576)    73728       add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 2, 2, 576)    2304        conv2d_19[0][0]
# __________________________________________________________________________________________________
# hard_swish_7 (HardSwish)        (None, 2, 2, 576)    0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (None, 2, 2, 576)    14400       hard_swish_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 2, 2, 576)    2304        depthwise_conv2d_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_35 (SeparableC (None, 32, 32, 32)   123         input_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 576)          0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 32, 32, 32)   128         separable_conv2d_35[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 1, 576)    0           global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# hard_swish_10 (HardSwish)       (None, 32, 32, 32)   0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 1, 1, 144)    82944       reshape_4[0][0]
# __________________________________________________________________________________________________
# attention_1 (Attention)         (None, 32, 32, 32)   1321        hard_swish_10[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 1, 1, 144)    0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_36 (SeparableC (None, 16, 16, 128)  4384        attention_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 1, 1, 576)    82944       activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 16, 16, 128)  512         separable_conv2d_36[0][0]
# __________________________________________________________________________________________________
# hard_sigmoid_11 (HardSigmoid)   (None, 1, 1, 576)    0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# hard_swish_11 (HardSwish)       (None, 16, 16, 128)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 2, 2, 576)    0           hard_swish_7[0][0]
#                                                                  hard_sigmoid_11[0][0]
# __________________________________________________________________________________________________
# attention_2 (Attention)         (None, 16, 16, 128)  20641       hard_swish_11[0][0]
# __________________________________________________________________________________________________
# hard_swish_8 (HardSwish)        (None, 2, 2, 576)    0           multiply_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_37 (SeparableC (None, 8, 8, 256)    33920       attention_2[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 2, 2, 128)    73728       hard_swish_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 8, 8, 256)    1024        separable_conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 2, 2, 128)    512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# hard_swish_12 (HardSwish)       (None, 8, 8, 256)    0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 2, 2, 128)    0           add_14[0][0]
#                                                                  batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# attention_3 (Attention)         (None, 8, 8, 256)    82241       hard_swish_12[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 2, 2, 1020)   130560      add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 8, 8, 1020)   261120      attention_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 2, 2, 1020)   4080        conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 8, 8, 1020)   4080        conv2d_24[0][0]
# __________________________________________________________________________________________________
# hard_swish_9 (HardSwish)        (None, 2, 2, 1020)   0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# hard_swish_13 (HardSwish)       (None, 8, 8, 1020)   0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 1020)         0           hard_swish_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 1020)         0           hard_swish_13[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 1, 1, 1020)   0           global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 1, 1020)   0           global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 1, 1, 1020)   0           reshape_5[0][0]
#                                                                  reshape_6[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 1, 1, 2)      2042        add_16[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 1, 1, 2)      0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1, 2)         0           activation_40[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 2)            0           lambda_1[0][0]
# ==================================================================================================
# Total params: 23,831,368
# Trainable params: 23,763,912
# Non-trainable params: 67,456
# __________________________________________________________________________________________________

# %%
# optimizer = SGD(lr=1e-3, momentum=0.9, nesterov=True)
optimizer = Adam()
model_top.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['acc'])
callback_list = [EarlyStopping(monitor='val_acc', patience=30), 
                 ReduceLROnPlateau(monitor='loss', factor=np.sqrt(0.5), cooldown=0, patience=5, min_lr=0.5e-5)]
output = model_top.fit_generator(ft_gen, steps_per_epoch=200, epochs=300,
                                  validation_data=validation_generator, validation_steps=len(validation_generator), callbacks=callback_list)
# Out:
# WARNING:tensorflow:From /home/www/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/300
# 200/200 [==============================] - 142s 709ms/step - loss: 0.7507 - acc: 0.5968 - val_loss: 0.3449 - val_acc: 0.7722
# Epoch 2/300
# 200/200 [==============================] - 113s 565ms/step - loss: 0.6513 - acc: 0.6622 - val_loss: 0.7875 - val_acc: 0.6020
# Epoch 3/300
# 200/200 [==============================] - 112s 561ms/step - loss: 0.6175 - acc: 0.6878 - val_loss: 1.0252 - val_acc: 0.6363
# Epoch 4/300
# 200/200 [==============================] - 109s 547ms/step - loss: 0.6058 - acc: 0.6899 - val_loss: 0.5850 - val_acc: 0.7619
# Epoch 5/300
# 200/200 [==============================] - 109s 546ms/step - loss: 0.5895 - acc: 0.6985 - val_loss: 0.2078 - val_acc: 0.7701
# Epoch 6/300
# 200/200 [==============================] - 113s 563ms/step - loss: 0.5815 - acc: 0.7038 - val_loss: 0.5158 - val_acc: 0.7253
# Epoch 7/300
# 200/200 [==============================] - 113s 564ms/step - loss: 0.5837 - acc: 0.7017 - val_loss: 0.5390 - val_acc: 0.7742
# Epoch 8/300
# 200/200 [==============================] - 112s 560ms/step - loss: 0.5733 - acc: 0.7191 - val_loss: 0.8694 - val_acc: 0.7238
# Epoch 9/300
# 200/200 [==============================] - 112s 561ms/step - loss: 0.5637 - acc: 0.7099 - val_loss: 0.5059 - val_acc: 0.7331
# Epoch 10/300
# 200/200 [==============================] - 111s 554ms/step - loss: 0.5455 - acc: 0.7365 - val_loss: 0.5122 - val_acc: 0.7787
# Epoch 11/300
# 200/200 [==============================] - 112s 558ms/step - loss: 0.5209 - acc: 0.7408 - val_loss: 1.0012 - val_acc: 0.5848
# Epoch 12/300
# 200/200 [==============================] - 110s 550ms/step - loss: 0.5206 - acc: 0.7421 - val_loss: 2.1857 - val_acc: 0.5346
# Epoch 13/300
# 200/200 [==============================] - 110s 548ms/step - loss: 0.5245 - acc: 0.7426 - val_loss: 0.4069 - val_acc: 0.7763
# Epoch 14/300
# 200/200 [==============================] - 115s 573ms/step - loss: 0.4961 - acc: 0.7623 - val_loss: 0.7687 - val_acc: 0.6896
# Epoch 15/300
# 200/200 [==============================] - 111s 557ms/step - loss: 0.4917 - acc: 0.7650 - val_loss: 0.2851 - val_acc: 0.8150
# Epoch 16/300
# 200/200 [==============================] - 114s 572ms/step - loss: 0.4779 - acc: 0.7714 - val_loss: 0.4563 - val_acc: 0.7562
# Epoch 17/300
# 200/200 [==============================] - 116s 579ms/step - loss: 0.4576 - acc: 0.7788 - val_loss: 0.1699 - val_acc: 0.7965
# Epoch 18/300
# 200/200 [==============================] - 114s 571ms/step - loss: 0.4446 - acc: 0.7917 - val_loss: 1.0795 - val_acc: 0.6945
# Epoch 19/300
# 200/200 [==============================] - 110s 548ms/step - loss: 0.4652 - acc: 0.7756 - val_loss: 0.2193 - val_acc: 0.8239
# Epoch 20/300
# 200/200 [==============================] - 112s 562ms/step - loss: 0.4351 - acc: 0.7928 - val_loss: 0.4193 - val_acc: 0.7698
# Epoch 21/300
# 200/200 [==============================] - 108s 541ms/step - loss: 0.4230 - acc: 0.7985 - val_loss: 0.2479 - val_acc: 0.8067
# Epoch 22/300
# 200/200 [==============================] - 105s 525ms/step - loss: 0.4156 - acc: 0.8084 - val_loss: 0.5100 - val_acc: 0.7632
# Epoch 23/300
# 200/200 [==============================] - 104s 522ms/step - loss: 0.4023 - acc: 0.8070 - val_loss: 1.5857 - val_acc: 0.7533
# Epoch 24/300
# 200/200 [==============================] - 99s 495ms/step - loss: 0.3996 - acc: 0.8155 - val_loss: 0.1497 - val_acc: 0.8287
# Epoch 25/300
# 200/200 [==============================] - 100s 502ms/step - loss: 0.3920 - acc: 0.8142 - val_loss: 0.4602 - val_acc: 0.8187
# Epoch 26/300
# 200/200 [==============================] - 102s 511ms/step - loss: 0.3639 - acc: 0.8322 - val_loss: 0.8431 - val_acc: 0.7512
# Epoch 27/300
# 200/200 [==============================] - 104s 522ms/step - loss: 0.3552 - acc: 0.8352 - val_loss: 0.6219 - val_acc: 0.8009
# Epoch 28/300
# 200/200 [==============================] - 99s 495ms/step - loss: 0.3524 - acc: 0.8385 - val_loss: 0.7194 - val_acc: 0.8166
# Epoch 29/300
# 200/200 [==============================] - 96s 480ms/step - loss: 0.3462 - acc: 0.8463 - val_loss: 0.1248 - val_acc: 0.8332
# Epoch 30/300
# 200/200 [==============================] - 96s 481ms/step - loss: 0.3366 - acc: 0.8459 - val_loss: 0.1023 - val_acc: 0.8573
# Epoch 31/300
# 200/200 [==============================] - 94s 472ms/step - loss: 0.3153 - acc: 0.8555 - val_loss: 1.1813 - val_acc: 0.7952
# Epoch 32/300
# 200/200 [==============================] - 97s 485ms/step - loss: 0.3139 - acc: 0.8571 - val_loss: 0.1671 - val_acc: 0.8612
# Epoch 33/300
# 200/200 [==============================] - 99s 494ms/step - loss: 0.2920 - acc: 0.8682 - val_loss: 0.1707 - val_acc: 0.8206
# Epoch 34/300
# 200/200 [==============================] - 99s 494ms/step - loss: 0.2922 - acc: 0.8648 - val_loss: 0.0217 - val_acc: 0.8704
# Epoch 35/300
# 200/200 [==============================] - 102s 511ms/step - loss: 0.2853 - acc: 0.8681 - val_loss: 0.1648 - val_acc: 0.8377
# Epoch 36/300
# 200/200 [==============================] - 99s 496ms/step - loss: 0.2732 - acc: 0.8775 - val_loss: 0.8828 - val_acc: 0.8340
# Epoch 37/300
# 200/200 [==============================] - 97s 485ms/step - loss: 0.2628 - acc: 0.8837 - val_loss: 0.6643 - val_acc: 0.8445
# Epoch 38/300
# 200/200 [==============================] - 95s 475ms/step - loss: 0.2408 - acc: 0.8940 - val_loss: 0.0617 - val_acc: 0.8886
# Epoch 39/300
# 200/200 [==============================] - 92s 461ms/step - loss: 0.2541 - acc: 0.8872 - val_loss: 0.0153 - val_acc: 0.8694
# Epoch 40/300
# 200/200 [==============================] - 92s 458ms/step - loss: 0.2512 - acc: 0.8870 - val_loss: 0.0319 - val_acc: 0.8951
# Epoch 41/300
# 200/200 [==============================] - 94s 469ms/step - loss: 0.2332 - acc: 0.8945 - val_loss: 0.1057 - val_acc: 0.8895
# Epoch 42/300
# 200/200 [==============================] - 93s 463ms/step - loss: 0.2411 - acc: 0.8886 - val_loss: 0.2056 - val_acc: 0.8753
# Epoch 43/300
# 200/200 [==============================] - 92s 461ms/step - loss: 0.2213 - acc: 0.8988 - val_loss: 0.3472 - val_acc: 0.8698
# Epoch 44/300
# 200/200 [==============================] - 94s 468ms/step - loss: 0.2157 - acc: 0.9082 - val_loss: 0.2471 - val_acc: 0.9036
# Epoch 45/300
# 200/200 [==============================] - 95s 475ms/step - loss: 0.2160 - acc: 0.9052 - val_loss: 0.0712 - val_acc: 0.9021
# Epoch 46/300
# 200/200 [==============================] - 98s 492ms/step - loss: 0.2112 - acc: 0.9128 - val_loss: 0.0200 - val_acc: 0.8940
# Epoch 47/300
# 200/200 [==============================] - 101s 505ms/step - loss: 0.2206 - acc: 0.9079 - val_loss: 0.0773 - val_acc: 0.8953
# Epoch 48/300
# 200/200 [==============================] - 100s 502ms/step - loss: 0.1953 - acc: 0.9138 - val_loss: 0.0099 - val_acc: 0.8855
# Epoch 49/300
# 200/200 [==============================] - 97s 485ms/step - loss: 0.1933 - acc: 0.9211 - val_loss: 0.0434 - val_acc: 0.9052
# Epoch 50/300
# 200/200 [==============================] - 94s 470ms/step - loss: 0.1863 - acc: 0.9186 - val_loss: 0.1820 - val_acc: 0.8466
# Epoch 51/300
# 200/200 [==============================] - 95s 475ms/step - loss: 0.1896 - acc: 0.9178 - val_loss: 0.1151 - val_acc: 0.8609
# Epoch 52/300
# 200/200 [==============================] - 97s 486ms/step - loss: 0.1849 - acc: 0.9207 - val_loss: 0.1150 - val_acc: 0.9139
# Epoch 53/300
# 200/200 [==============================] - 98s 489ms/step - loss: 0.1612 - acc: 0.9337 - val_loss: 0.1155 - val_acc: 0.9377
# Epoch 54/300
# 200/200 [==============================] - 101s 504ms/step - loss: 0.1623 - acc: 0.9302 - val_loss: 0.1068 - val_acc: 0.9199
# Epoch 55/300
# 200/200 [==============================] - 102s 509ms/step - loss: 0.1667 - acc: 0.9314 - val_loss: 0.0995 - val_acc: 0.8894
# Epoch 56/300
# 200/200 [==============================] - 104s 519ms/step - loss: 0.1674 - acc: 0.9235 - val_loss: 0.0125 - val_acc: 0.9091
# Epoch 57/300
# 200/200 [==============================] - 100s 498ms/step - loss: 0.1742 - acc: 0.9332 - val_loss: 0.0380 - val_acc: 0.9183
# Epoch 58/300
# 200/200 [==============================] - 98s 488ms/step - loss: 0.1436 - acc: 0.9403 - val_loss: 0.0272 - val_acc: 0.9215
# Epoch 59/300
# 200/200 [==============================] - 98s 489ms/step - loss: 0.1432 - acc: 0.9411 - val_loss: 0.0069 - val_acc: 0.9428
# Epoch 60/300
# 200/200 [==============================] - 98s 490ms/step - loss: 0.1431 - acc: 0.9419 - val_loss: 0.0199 - val_acc: 0.9299
# Epoch 61/300
# 200/200 [==============================] - 101s 506ms/step - loss: 0.1333 - acc: 0.9480 - val_loss: 0.0299 - val_acc: 0.9213
# Epoch 62/300
# 200/200 [==============================] - 101s 505ms/step - loss: 0.1417 - acc: 0.9373 - val_loss: 0.0435 - val_acc: 0.9223
# Epoch 63/300
# 200/200 [==============================] - 101s 504ms/step - loss: 0.1314 - acc: 0.9443 - val_loss: 0.0101 - val_acc: 0.9343
# Epoch 64/300
# 200/200 [==============================] - 100s 500ms/step - loss: 0.1343 - acc: 0.9386 - val_loss: 0.1298 - val_acc: 0.8971
# Epoch 65/300
# 200/200 [==============================] - 96s 479ms/step - loss: 0.1285 - acc: 0.9486 - val_loss: 0.0148 - val_acc: 0.9398
# Epoch 66/300
# 200/200 [==============================] - 97s 484ms/step - loss: 0.1245 - acc: 0.9517 - val_loss: 0.0871 - val_acc: 0.9245
# Epoch 67/300
# 200/200 [==============================] - 93s 465ms/step - loss: 0.1279 - acc: 0.9473 - val_loss: 0.1725 - val_acc: 0.9495
# Epoch 68/300
# 200/200 [==============================] - 97s 487ms/step - loss: 0.1187 - acc: 0.9509 - val_loss: 0.0658 - val_acc: 0.9003
# Epoch 69/300
# 200/200 [==============================] - 98s 488ms/step - loss: 0.1157 - acc: 0.9562 - val_loss: 0.0088 - val_acc: 0.9427
# Epoch 70/300
# 200/200 [==============================] - 97s 483ms/step - loss: 0.1194 - acc: 0.9515 - val_loss: 0.0039 - val_acc: 0.8425
# Epoch 71/300
# 200/200 [==============================] - 94s 472ms/step - loss: 0.1182 - acc: 0.9509 - val_loss: 0.0042 - val_acc: 0.8687
# Epoch 72/300
# 200/200 [==============================] - 96s 482ms/step - loss: 0.1228 - acc: 0.9484 - val_loss: 0.0047 - val_acc: 0.9432
# Epoch 73/300
# 200/200 [==============================] - 98s 489ms/step - loss: 0.1147 - acc: 0.9556 - val_loss: 0.0066 - val_acc: 0.9356
# Epoch 74/300
# 200/200 [==============================] - 97s 484ms/step - loss: 0.1113 - acc: 0.9553 - val_loss: 0.0077 - val_acc: 0.8535
# Epoch 75/300
# 200/200 [==============================] - 97s 483ms/step - loss: 0.1114 - acc: 0.9545 - val_loss: 0.0836 - val_acc: 0.9571
# Epoch 76/300
# 200/200 [==============================] - 93s 466ms/step - loss: 0.1164 - acc: 0.9548 - val_loss: 0.0081 - val_acc: 0.9357
# Epoch 77/300
# 200/200 [==============================] - 95s 475ms/step - loss: 0.1116 - acc: 0.9569 - val_loss: 0.0045 - val_acc: 0.9002
# Epoch 78/300
# 200/200 [==============================] - 94s 471ms/step - loss: 0.1109 - acc: 0.9560 - val_loss: 0.0098 - val_acc: 0.9512
# Epoch 79/300
# 200/200 [==============================] - 96s 481ms/step - loss: 0.1043 - acc: 0.9588 - val_loss: 0.1569 - val_acc: 0.9095
# Epoch 80/300
# 200/200 [==============================] - 96s 479ms/step - loss: 0.1080 - acc: 0.9550 - val_loss: 0.0243 - val_acc: 0.9136
# Epoch 81/300
# 200/200 [==============================] - 98s 488ms/step - loss: 0.1010 - acc: 0.9594 - val_loss: 0.0163 - val_acc: 0.9472
# Epoch 82/300
# 200/200 [==============================] - 101s 504ms/step - loss: 0.1015 - acc: 0.9602 - val_loss: 0.0090 - val_acc: 0.9328
# Epoch 83/300
# 200/200 [==============================] - 101s 504ms/step - loss: 0.1021 - acc: 0.9569 - val_loss: 0.0207 - val_acc: 0.9548
# Epoch 84/300
# 200/200 [==============================] - 98s 491ms/step - loss: 0.0969 - acc: 0.9600 - val_loss: 0.1937 - val_acc: 0.9279
# Epoch 85/300
# 200/200 [==============================] - 94s 469ms/step - loss: 0.0956 - acc: 0.9596 - val_loss: 0.0077 - val_acc: 0.9437
# Epoch 86/300
# 200/200 [==============================] - 95s 477ms/step - loss: 0.0979 - acc: 0.9605 - val_loss: 0.0070 - val_acc: 0.9638
# Epoch 87/300
# 200/200 [==============================] - 99s 493ms/step - loss: 0.1017 - acc: 0.9556 - val_loss: 0.0151 - val_acc: 0.9599
# Epoch 88/300
# 200/200 [==============================] - 100s 500ms/step - loss: 0.1020 - acc: 0.9611 - val_loss: 0.0162 - val_acc: 0.9584
# Epoch 89/300
# 200/200 [==============================] - 102s 508ms/step - loss: 0.0925 - acc: 0.9586 - val_loss: 0.0027 - val_acc: 0.8986
# Epoch 90/300
# 200/200 [==============================] - 100s 500ms/step - loss: 0.0909 - acc: 0.9663 - val_loss: 0.0846 - val_acc: 0.9554
# Epoch 91/300
# 200/200 [==============================] - 86s 431ms/step - loss: 0.0879 - acc: 0.9657 - val_loss: 0.0030 - val_acc: 0.9351
# Epoch 92/300
# 200/200 [==============================] - 85s 427ms/step - loss: 0.0911 - acc: 0.9645 - val_loss: 0.0042 - val_acc: 0.7181
# Epoch 93/300
# 200/200 [==============================] - 81s 404ms/step - loss: 0.0937 - acc: 0.9618 - val_loss: 0.0034 - val_acc: 0.8659
# Epoch 94/300
# 200/200 [==============================] - 82s 412ms/step - loss: 0.0894 - acc: 0.9648 - val_loss: 0.0034 - val_acc: 0.9148
# Epoch 95/300
# 200/200 [==============================] - 81s 406ms/step - loss: 0.0897 - acc: 0.9625 - val_loss: 0.0166 - val_acc: 0.9558
# Epoch 96/300
# 200/200 [==============================] - 82s 409ms/step - loss: 0.0903 - acc: 0.9631 - val_loss: 0.0071 - val_acc: 0.9629
# Epoch 97/300
# 200/200 [==============================] - 80s 398ms/step - loss: 0.0676 - acc: 0.9702 - val_loss: 0.0091 - val_acc: 0.9611
# Epoch 98/300
# 200/200 [==============================] - 80s 402ms/step - loss: 0.0814 - acc: 0.9663 - val_loss: 0.0286 - val_acc: 0.9573
# Epoch 99/300
# 200/200 [==============================] - 79s 394ms/step - loss: 0.0742 - acc: 0.9699 - val_loss: 0.0044 - val_acc: 0.9468
# Epoch 100/300
# 200/200 [==============================] - 79s 396ms/step - loss: 0.0704 - acc: 0.9706 - val_loss: 0.0049 - val_acc: 0.9434
# Epoch 101/300
# 200/200 [==============================] - 78s 391ms/step - loss: 0.0680 - acc: 0.9723 - val_loss: 0.1099 - val_acc: 0.9538
# Epoch 102/300
# 200/200 [==============================] - 77s 386ms/step - loss: 0.0674 - acc: 0.9713 - val_loss: 0.0023 - val_acc: 0.9649
# Epoch 103/300
# 200/200 [==============================] - 77s 386ms/step - loss: 0.0639 - acc: 0.9730 - val_loss: 0.0046 - val_acc: 0.9725
# Epoch 104/300
# 200/200 [==============================] - 76s 378ms/step - loss: 0.0637 - acc: 0.9745 - val_loss: 0.0035 - val_acc: 0.9709
# Epoch 105/300
# 200/200 [==============================] - 75s 376ms/step - loss: 0.0599 - acc: 0.9744 - val_loss: 0.0036 - val_acc: 0.9627
# Epoch 106/300
# 200/200 [==============================] - 76s 379ms/step - loss: 0.0585 - acc: 0.9768 - val_loss: 0.0034 - val_acc: 0.9632
# Epoch 107/300
# 200/200 [==============================] - 75s 377ms/step - loss: 0.0682 - acc: 0.9713 - val_loss: 0.0026 - val_acc: 0.9706
# Epoch 108/300
# 200/200 [==============================] - 77s 387ms/step - loss: 0.0567 - acc: 0.9768 - val_loss: 0.0020 - val_acc: 0.9636
# Epoch 109/300
# 200/200 [==============================] - 75s 377ms/step - loss: 0.0613 - acc: 0.9723 - val_loss: 0.1733 - val_acc: 0.9509
# Epoch 110/300
# 200/200 [==============================] - 76s 381ms/step - loss: 0.0623 - acc: 0.9761 - val_loss: 0.0060 - val_acc: 0.9702
# Epoch 111/300
# 200/200 [==============================] - 75s 377ms/step - loss: 0.0588 - acc: 0.9750 - val_loss: 0.0026 - val_acc: 0.9480
# Epoch 112/300
# 200/200 [==============================] - 75s 377ms/step - loss: 0.0575 - acc: 0.9751 - val_loss: 0.0368 - val_acc: 0.9583
# Epoch 113/300
# 200/200 [==============================] - 75s 375ms/step - loss: 0.0600 - acc: 0.9770 - val_loss: 0.0021 - val_acc: 0.8678
# Epoch 114/300
# 200/200 [==============================] - 76s 380ms/step - loss: 0.0605 - acc: 0.9753 - val_loss: 0.0022 - val_acc: 0.9541
# Epoch 115/300
# 200/200 [==============================] - 77s 385ms/step - loss: 0.0565 - acc: 0.9754 - val_loss: 0.0038 - val_acc: 0.9702
# Epoch 116/300
# 200/200 [==============================] - 77s 386ms/step - loss: 0.0537 - acc: 0.9792 - val_loss: 0.0025 - val_acc: 0.9658
# Epoch 117/300
# 200/200 [==============================] - 78s 392ms/step - loss: 0.0519 - acc: 0.9772 - val_loss: 0.0022 - val_acc: 0.9766
# Epoch 118/300
# 200/200 [==============================] - 79s 395ms/step - loss: 0.0575 - acc: 0.9763 - val_loss: 0.0032 - val_acc: 0.9722
# Epoch 119/300
# 200/200 [==============================] - 79s 397ms/step - loss: 0.0487 - acc: 0.9800 - val_loss: 0.0017 - val_acc: 0.9570
# Epoch 120/300
# 200/200 [==============================] - 80s 398ms/step - loss: 0.0515 - acc: 0.9787 - val_loss: 0.0016 - val_acc: 0.9392
# Epoch 121/300
# 200/200 [==============================] - 70s 352ms/step - loss: 0.0523 - acc: 0.9797 - val_loss: 0.0060 - val_acc: 0.9743
# Epoch 122/300
# 200/200 [==============================] - 71s 355ms/step - loss: 0.0572 - acc: 0.9759 - val_loss: 0.0016 - val_acc: 0.9572
# Epoch 123/300
# 200/200 [==============================] - 65s 327ms/step - loss: 0.0469 - acc: 0.9799 - val_loss: 0.0018 - val_acc: 0.9700
# Epoch 124/300
# 200/200 [==============================] - 64s 318ms/step - loss: 0.0490 - acc: 0.9790 - val_loss: 0.0019 - val_acc: 0.9737
# Epoch 125/300
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0476 - acc: 0.9797 - val_loss: 0.0104 - val_acc: 0.9754
# Epoch 126/300
# 200/200 [==============================] - 64s 320ms/step - loss: 0.0537 - acc: 0.9761 - val_loss: 0.0018 - val_acc: 0.9749
# Epoch 127/300
# 200/200 [==============================] - 65s 323ms/step - loss: 0.0453 - acc: 0.9805 - val_loss: 0.0018 - val_acc: 0.9704
# Epoch 128/300
# 200/200 [==============================] - 65s 323ms/step - loss: 0.0529 - acc: 0.9777 - val_loss: 0.0016 - val_acc: 0.9688
# Epoch 129/300
# 200/200 [==============================] - 64s 318ms/step - loss: 0.0548 - acc: 0.9770 - val_loss: 0.0024 - val_acc: 0.9727
# Epoch 130/300
# 200/200 [==============================] - 64s 322ms/step - loss: 0.0442 - acc: 0.9804 - val_loss: 0.0020 - val_acc: 0.9744
# Epoch 131/300
# 200/200 [==============================] - 64s 321ms/step - loss: 0.0460 - acc: 0.9814 - val_loss: 0.0041 - val_acc: 0.9733
# Epoch 132/300
# 200/200 [==============================] - 65s 324ms/step - loss: 0.0509 - acc: 0.9791 - val_loss: 0.0013 - val_acc: 0.9734
# Epoch 133/300
# 200/200 [==============================] - 67s 334ms/step - loss: 0.0476 - acc: 0.9791 - val_loss: 0.0051 - val_acc: 0.9589
# Epoch 134/300
# 200/200 [==============================] - 64s 322ms/step - loss: 0.0484 - acc: 0.9795 - val_loss: 0.0036 - val_acc: 0.9692
# Epoch 135/300
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0470 - acc: 0.9804 - val_loss: 0.0013 - val_acc: 0.9719
# Epoch 136/300
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0457 - acc: 0.9815 - val_loss: 0.0014 - val_acc: 0.9721
# Epoch 137/300
# 200/200 [==============================] - 64s 322ms/step - loss: 0.0467 - acc: 0.9801 - val_loss: 0.0012 - val_acc: 0.9553
# Epoch 138/300
# 200/200 [==============================] - 65s 324ms/step - loss: 0.0450 - acc: 0.9814 - val_loss: 0.0017 - val_acc: 0.9789
# Epoch 139/300
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0416 - acc: 0.9813 - val_loss: 0.0011 - val_acc: 0.9766
# Epoch 140/300
# 200/200 [==============================] - 65s 323ms/step - loss: 0.0456 - acc: 0.9814 - val_loss: 0.0012 - val_acc: 0.9731
# Epoch 141/300
# 200/200 [==============================] - 64s 322ms/step - loss: 0.0443 - acc: 0.9821 - val_loss: 0.0012 - val_acc: 0.9752
# Epoch 142/300
# 200/200 [==============================] - 64s 322ms/step - loss: 0.0469 - acc: 0.9787 - val_loss: 0.0012 - val_acc: 0.9694
# Epoch 143/300
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0404 - acc: 0.9843 - val_loss: 0.0019 - val_acc: 0.9771
# Epoch 144/300
# 200/200 [==============================] - 64s 321ms/step - loss: 0.0441 - acc: 0.9803 - val_loss: 0.0013 - val_acc: 0.9778
# Epoch 145/300
# 200/200 [==============================] - 64s 320ms/step - loss: 0.0405 - acc: 0.9836 - val_loss: 0.0013 - val_acc: 0.9743
# Epoch 146/300
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0397 - acc: 0.9833 - val_loss: 0.0011 - val_acc: 0.9716
# Epoch 147/300
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0447 - acc: 0.9814 - val_loss: 0.0010 - val_acc: 0.9689
# Epoch 148/300
# 200/200 [==============================] - 65s 323ms/step - loss: 0.0426 - acc: 0.9818 - val_loss: 0.0011 - val_acc: 0.9778
# Epoch 149/300
# 200/200 [==============================] - 65s 323ms/step - loss: 0.0421 - acc: 0.9816 - val_loss: 0.0011 - val_acc: 0.9694
# Epoch 150/300
# 200/200 [==============================] - 64s 320ms/step - loss: 0.0415 - acc: 0.9827 - val_loss: 0.0010 - val_acc: 0.9753
# Epoch 151/300
# 200/200 [==============================] - 64s 320ms/step - loss: 0.0389 - acc: 0.9846 - val_loss: 0.0011 - val_acc: 0.9744
# Epoch 152/300
# 200/200 [==============================] - 65s 323ms/step - loss: 0.0456 - acc: 0.9787 - val_loss: 9.7924e-04 - val_acc: 0.9698
# Epoch 153/300
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0418 - acc: 0.9824 - val_loss: 0.0013 - val_acc: 0.9703
# Epoch 154/300
# 200/200 [==============================] - 67s 335ms/step - loss: 0.0412 - acc: 0.9822 - val_loss: 0.0014 - val_acc: 0.9741
# Epoch 155/300
# 200/200 [==============================] - 64s 321ms/step - loss: 0.0430 - acc: 0.9838 - val_loss: 0.0017 - val_acc: 0.9763
# Epoch 156/300
# 200/200 [==============================] - 65s 324ms/step - loss: 0.0418 - acc: 0.9828 - val_loss: 0.0015 - val_acc: 0.9770
# Epoch 157/300
# 200/200 [==============================] - 64s 321ms/step - loss: 0.0410 - acc: 0.9817 - val_loss: 0.0013 - val_acc: 0.9752
# Epoch 158/300
# 200/200 [==============================] - 64s 320ms/step - loss: 0.0399 - acc: 0.9839 - val_loss: 0.0014 - val_acc: 0.9731
# Epoch 159/300
# 200/200 [==============================] - 65s 324ms/step - loss: 0.0368 - acc: 0.9827 - val_loss: 0.0018 - val_acc: 0.9766
# Epoch 160/300
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0351 - acc: 0.9844 - val_loss: 0.0013 - val_acc: 0.9768
# Epoch 161/300
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0384 - acc: 0.9846 - val_loss: 0.0012 - val_acc: 0.9791
# Epoch 162/300
# 200/200 [==============================] - 65s 327ms/step - loss: 0.0411 - acc: 0.9816 - val_loss: 9.6359e-04 - val_acc: 0.9762
# Epoch 163/300
# 200/200 [==============================] - 64s 322ms/step - loss: 0.0384 - acc: 0.9837 - val_loss: 0.0010 - val_acc: 0.9747
# Epoch 164/300
# 200/200 [==============================] - 66s 328ms/step - loss: 0.0411 - acc: 0.9819 - val_loss: 0.0015 - val_acc: 0.9767
# Epoch 165/300
# 200/200 [==============================] - 66s 331ms/step - loss: 0.0306 - acc: 0.9883 - val_loss: 0.0014 - val_acc: 0.9793
# Epoch 166/300
# 200/200 [==============================] - 65s 324ms/step - loss: 0.0377 - acc: 0.9836 - val_loss: 0.0012 - val_acc: 0.9752
# Epoch 167/300
# 200/200 [==============================] - 65s 327ms/step - loss: 0.0390 - acc: 0.9834 - val_loss: 9.6745e-04 - val_acc: 0.9685
# Epoch 168/300
# 200/200 [==============================] - 65s 324ms/step - loss: 0.0376 - acc: 0.9843 - val_loss: 0.0013 - val_acc: 0.9793
# Epoch 169/300
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0367 - acc: 0.9831 - val_loss: 0.0012 - val_acc: 0.9758
# Epoch 170/300
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0320 - acc: 0.9844 - val_loss: 0.0010 - val_acc: 0.9772
# Epoch 171/300
# 200/200 [==============================] - 65s 327ms/step - loss: 0.0344 - acc: 0.9855 - val_loss: 0.0010 - val_acc: 0.9793
# Epoch 172/300
# 200/200 [==============================] - 66s 331ms/step - loss: 0.0362 - acc: 0.9824 - val_loss: 9.9479e-04 - val_acc: 0.9786
# Epoch 173/300
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0338 - acc: 0.9858 - val_loss: 0.0011 - val_acc: 0.9781
# Epoch 174/300
# 200/200 [==============================] - 65s 324ms/step - loss: 0.0377 - acc: 0.9846 - val_loss: 0.0016 - val_acc: 0.9795
# Epoch 175/300
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0369 - acc: 0.9834 - val_loss: 0.0031 - val_acc: 0.9803
# Epoch 176/300
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0354 - acc: 0.9850 - val_loss: 0.0011 - val_acc: 0.9783
# Epoch 177/300
# 200/200 [==============================] - 66s 328ms/step - loss: 0.0339 - acc: 0.9839 - val_loss: 0.0013 - val_acc: 0.9796
# Epoch 178/300
# 200/200 [==============================] - 65s 327ms/step - loss: 0.0314 - acc: 0.9874 - val_loss: 0.0012 - val_acc: 0.9778
# Epoch 179/300
# 200/200 [==============================] - 64s 321ms/step - loss: 0.0326 - acc: 0.9836 - val_loss: 8.8878e-04 - val_acc: 0.9749
# Epoch 180/300
# 200/200 [==============================] - 66s 330ms/step - loss: 0.0362 - acc: 0.9846 - val_loss: 0.0015 - val_acc: 0.9766
# Epoch 181/300
# 200/200 [==============================] - 64s 322ms/step - loss: 0.0363 - acc: 0.9831 - val_loss: 8.1035e-04 - val_acc: 0.9711
# Epoch 182/300
# 200/200 [==============================] - 65s 327ms/step - loss: 0.0351 - acc: 0.9854 - val_loss: 9.4440e-04 - val_acc: 0.9778
# Epoch 183/300
# 200/200 [==============================] - 66s 328ms/step - loss: 0.0304 - acc: 0.9860 - val_loss: 9.3953e-04 - val_acc: 0.9793
# Epoch 184/300
# 200/200 [==============================] - 65s 327ms/step - loss: 0.0319 - acc: 0.9885 - val_loss: 8.2236e-04 - val_acc: 0.9796
# Epoch 185/300
# 200/200 [==============================] - 64s 322ms/step - loss: 0.0312 - acc: 0.9856 - val_loss: 7.7783e-04 - val_acc: 0.9783
# Epoch 186/300
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0268 - acc: 0.9880 - val_loss: 0.0010 - val_acc: 0.9795
# Epoch 187/300
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0342 - acc: 0.9834 - val_loss: 7.6585e-04 - val_acc: 0.9775
# Epoch 188/300
# 200/200 [==============================] - 66s 328ms/step - loss: 0.0285 - acc: 0.9872 - val_loss: 8.7341e-04 - val_acc: 0.9774
# Epoch 189/300
# 200/200 [==============================] - 66s 331ms/step - loss: 0.0346 - acc: 0.9858 - val_loss: 0.0011 - val_acc: 0.9792
# Epoch 190/300
# 200/200 [==============================] - 67s 337ms/step - loss: 0.0317 - acc: 0.9860 - val_loss: 9.3759e-04 - val_acc: 0.9778
# Epoch 191/300
# 200/200 [==============================] - 66s 331ms/step - loss: 0.0357 - acc: 0.9839 - val_loss: 8.2187e-04 - val_acc: 0.9781
# Epoch 192/300
# 200/200 [==============================] - 65s 327ms/step - loss: 0.0356 - acc: 0.9854 - val_loss: 8.2315e-04 - val_acc: 0.9779
# Epoch 193/300
# 200/200 [==============================] - 66s 332ms/step - loss: 0.0307 - acc: 0.9863 - val_loss: 8.9686e-04 - val_acc: 0.9778
# Epoch 194/300
# 200/200 [==============================] - 67s 336ms/step - loss: 0.0317 - acc: 0.9857 - val_loss: 7.7343e-04 - val_acc: 0.9795
# Epoch 195/300
# 200/200 [==============================] - 65s 323ms/step - loss: 0.0358 - acc: 0.9850 - val_loss: 7.8672e-04 - val_acc: 0.9786
# Epoch 196/300
# 200/200 [==============================] - 65s 324ms/step - loss: 0.0304 - acc: 0.9850 - val_loss: 7.8363e-04 - val_acc: 0.9789
# Epoch 197/300
# 200/200 [==============================] - 64s 318ms/step - loss: 0.0288 - acc: 0.9882 - val_loss: 8.4109e-04 - val_acc: 0.9797
# Epoch 198/300
# 200/200 [==============================] - 65s 323ms/step - loss: 0.0300 - acc: 0.9868 - val_loss: 8.0939e-04 - val_acc: 0.9796
# Epoch 199/300
# 200/200 [==============================] - 65s 324ms/step - loss: 0.0304 - acc: 0.9861 - val_loss: 7.4490e-04 - val_acc: 0.9796
# Epoch 200/300
# 200/200 [==============================] - 67s 335ms/step - loss: 0.0303 - acc: 0.9869 - val_loss: 7.1410e-04 - val_acc: 0.9784
# Epoch 201/300
# 200/200 [==============================] - 66s 332ms/step - loss: 0.0315 - acc: 0.9857 - val_loss: 7.1675e-04 - val_acc: 0.9783
# Epoch 202/300
# 200/200 [==============================] - 64s 321ms/step - loss: 0.0326 - acc: 0.9855 - val_loss: 7.1681e-04 - val_acc: 0.9787
# Epoch 203/300
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0301 - acc: 0.9868 - val_loss: 8.1604e-04 - val_acc: 0.9789
# Epoch 204/300
# 200/200 [==============================] - 64s 318ms/step - loss: 0.0290 - acc: 0.9886 - val_loss: 7.6911e-04 - val_acc: 0.9792
# Epoch 205/300
# 200/200 [==============================] - 66s 331ms/step - loss: 0.0305 - acc: 0.9854 - val_loss: 7.3270e-04 - val_acc: 0.9789

# %%
output_score50 = []
output_class50 = []
answer_class50 = []
answer_class50_1 =[]

for i in trange(len(test50_generator)):
    output50 = model_top.predict_on_batch(test50_generator[i][0])
    output_score50.append(output50)
    answer_class50.append(test50_generator[i][1])
    
output_score50 = np.concatenate(output_score50)
answer_class50 = np.concatenate(answer_class50)

output_class50 = np.argmax(output_score50, axis=1)
answer_class50_1 = np.argmax(answer_class50, axis=1)

print(output_class50)
print(answer_class50_1)
# Out:
# 100%|██████████| 625/625 [01:53<00:00,  5.51it/s]
# [0 0 0 ... 1 1 1]
# [0 0 0 ... 1 1 1]

# %%
cm50 = confusion_matrix(answer_class50_1, output_class50)
report50 = classification_report(answer_class50_1, output_class50)

recall50 = cm50[0][0] / (cm50[0][0] + cm50[0][1])
fallout50 = cm50[1][0] / (cm50[1][0] + cm50[1][1])

fpr50, tpr50, thresholds50 = roc_curve(answer_class50_1, output_score50[:, 1], pos_label=1.)
eer50 = brentq(lambda x : 1. - x - interp1d(fpr50, tpr50)(x), 0., 1.)
thresh50 = interp1d(fpr50, thresholds50)(eer50)

print(report50)
print(cm50)
print("AUROC: %f" %(roc_auc_score(answer_class50_1, output_score50[:, 1])))
print(thresh50)
print('test_acc: ', len(output_class50[np.equal(output_class50, answer_class50_1)]) / len(output_class50))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     10000
#            1       0.98      0.98      0.98     10000
#
#     accuracy                           0.98     20000
#    macro avg       0.98      0.98      0.98     20000
# weighted avg       0.98      0.98      0.98     20000
#
# [[9796  204]
#  [ 162 9838]]
# AUROC: 0.997316
# 0.5683616995811059
# test_acc:  0.9817

# %%
model_top.save("/home/www/fake_detection/model/face2face_xception_ft.h5")
